# %%
import pandas as pd
import pickle
from collections import defaultdict
from leak_common import get_domain, find_prominence
import matplotlib.pyplot as plt

# %%
with open('../pkls_csvs/extra_tracker_domains.pkl', 'rb') as handle:
    extra_tracker_domains = pickle.load(handle)

# %% [markdown]
# # Read from pickles

# %%
log_details = pd.read_pickle("../pkls_csvs/nyc_log_details.pkl")
df = pd.read_csv("../pkls_csvs/desktop_no_action_nyc_crawl.csv", sep='\t', encoding='utf-8')
## Due to copyright restrictions, we can't share categories info
# with open('../pkls_csvs/categories.pkl', 'rb') as handle:
#     sites_categories = pickle.load(handle)

# %% [markdown]
# # Additional Columns

# %%
df['is_blocked'] = df.easy_list_blocked | df.easy_privacy_blocked | df.disconnect_blocked | df.whotracksme_blocked | (df.tds_blocked) | (df.ublock_blocked) | (df.request_url_domain.isin(extra_tracker_domains))

# %%
df['tracker_related'] = df.third_party_req & df.is_blocked

# %% [markdown]
# # All Requests

# %%
all_reqs = df
unique_all_reqs = all_reqs.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'])
all_reqs_email = all_reqs[all_reqs.search_type == 'email']
unique_all_reqs_email = all_reqs_email.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'])

# %%
print('all_reqs: ', len(all_reqs))
print('unique_all_reqs: ', len(unique_all_reqs))
print('all_reqs_email: ', len(all_reqs_email))
print('unique_all_reqs_email: ', len(unique_all_reqs_email))
# Out:
# all_reqs:  41936
# unique_all_reqs:  21156
# all_reqs_email:  38924
# unique_all_reqs_email:  19791

# %% [markdown]
# # Third Party Requests

# %%
third_party_reqs = df[df.third_party_req & ~df.is_req_off_site_direction]
unique_third_party_reqs = third_party_reqs.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'])
third_party_reqs_email = third_party_reqs[third_party_reqs.search_type == 'email']
unique_third_party_reqs_email = third_party_reqs_email.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'])

# %%
print('third_party_reqs: ', len(third_party_reqs))
print('unique_third_party_reqs: ', len(unique_third_party_reqs))
print('third_party_reqs_email: ', len(third_party_reqs_email))
print('unique_third_party_reqs_email: ', len(unique_third_party_reqs_email))
# Out:
# third_party_reqs:  32583
# unique_third_party_reqs:  17898
# third_party_reqs_email:  32004
# unique_third_party_reqs_email:  17680

# %% [markdown]
# # Tracking Related Requests

# %%
tracker_related_reqs_df = df[~df.is_req_off_site_direction & (df.leak_type!='response_cookie_leaks') & (df.leak_type!='response_location_leaks') &(df.tracker_related) & ((df.final_url_domain == df.last_page_domain) | (df.initial_url == df.last_page_domain))]
unique_tracking_related_df = tracker_related_reqs_df.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'],keep='last')
email_leaks = tracker_related_reqs_df[tracker_related_reqs_df.search_type == 'email']
unique_email_leaks = email_leaks.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'])

# %%
print('tracker_related_reqs_df: ', len(tracker_related_reqs_df))
print('unique_tracking_related_df: ', len(unique_tracking_related_df))
print('email_leaks: ', len(email_leaks))
print('unique_email_leaks: ', len(unique_email_leaks))
# Out:
# tracker_related_reqs_df:  22295
# unique_tracking_related_df:  12747
# email_leaks:  21898
# unique_email_leaks:  12621

# %% [markdown]
# # High Level Statistics

# %%
print('Distinct websites where emails are leaked to both 1st, 3rd parties and tracker domains: ',len(all_reqs_email.drop_duplicates('initial_hostname')))
print('Distinct websites where emails are leaked to both 3rd parties and tracker domains: ',len(unique_third_party_reqs_email.drop_duplicates('initial_hostname')))
print('Distinct websites where emails are leaked to only tracker domains: ',len(unique_email_leaks.drop_duplicates('initial_hostname')))
# Out:
# Distinct websites where emails are leaked to both 1st, 3rd parties and tracker domains:  5518
# Distinct websites where emails are leaked to both 3rd parties and tracker domains:  3790
# Distinct websites where emails are leaked to only tracker domains:  2950

# %% [markdown]
# # Prominence

# %%
prominence_list = find_prominence(unique_tracking_related_df[unique_tracking_related_df.search_type=='email'])

# %%
prominence_df = pd.DataFrame(prominence_list, columns=['domain','prominence', 'number_of_sites'])

# %%
prominence_df.sort_values('prominence',ascending=False).head(20)
# Out:
#                 domain  prominence  number_of_sites
# 6            rlcdn.com    0.055384              524
# 25         taboola.com    0.049900              383
# 42         bouncex.net    0.022474              189
# 10         bizible.com    0.021203              191
# 39          zenaps.com    0.011115              119
# 40           awin1.com    0.011092              118
# 5        fullstory.com    0.010560              230
# 21       listrakbi.com    0.006596              226
# 13          pippio.com    0.006513              138
# 43        smarterhq.io    0.006382               32
# 3            yahoo.com    0.006225              255
# 11          adroll.com    0.004859              122
# 4            yandex.ru    0.004808              141
# 15          criteo.com    0.004601              134
# 17         addthis.com    0.004590              133
# 16          dotomi.com    0.004590              133
# 14            agkn.com    0.004590              133
# 18  yieldoptimizer.com    0.004384              131
# 19        snapchat.com    0.004384              131
# 20     doubleclick.net    0.004384              131

# %% [markdown]
# ## Leak types

# %%
unique_tracking_related_df.leak_type.value_counts()
# Out:
# url_leaks     11389
# post_leaks     1358
# Name: leak_type, dtype: int64

# %% [markdown]
# ## Email leaks

# %%
unique_email_leaks[unique_email_leaks['rank_of_site']<2000].drop_duplicates('initial_url').sort_values('rank_of_site')[['initial_url', 'rank_of_site']].head(12)
# Out:
#                initial_url  rank_of_site
# 7754             issuu.com            95
# 15237  businessinsider.com           128
# 12214         usatoday.com           154
# 30632             time.com           191
# 18747            udemy.com           196
# 36995       healthline.com           217
# 26711          foxnews.com           234
# 37767           trello.com           242
# 19331         theverge.com           278
# 12788            webmd.com           288
# 21553          shopify.com           300
# 31343         marriott.com           328

# %%
distinct_websites_email_leaks = unique_email_leaks.drop_duplicates('initial_hostname')

# %%
unique_email_leaks.encoding.value_counts()
# Out:
# sha256                          2173
# urlencode-sha256                1857
# md5                             1752
# urlencode-md5                   1666
# sha1                            1062
# urlencode-sha1                  1022
# unencoded                        889
# urlencode                        628
# urlencode-sha_salted_1           237
# sha_salted_1                     237
# base64                           229
# lzstring-urlencode               195
# urlencode-lzstring-urlencode     194
# urlencode-base64                 186
# urlencode-urlencode              168
# urlencode-custom_map_1            74
# base64-sha1                       34
# base64-sha256                      8
# base64-md5                         3
# sha512                             2
# urlencode-sha512                   2
# base64-urlencode                   2
# base64-base64                      1
# Name: encoding, dtype: int64

# %% [markdown]
# ## Tracked But NOT Sniffed

# %%
email_leaks[email_leaks.email_sniffed==False].drop_duplicates('initial_hostname')
# Out:
#                                               search search_type  \
# 0                   cosicadam0+houston.org@gmail.com       email
# 478                      cosicadam0+bruna.nl@gmail.c       email
# 495    cosicadam0+democratandchronicle.com@gmail.com       email
# 618     cosicadam0+burlingtonfreepress.com@gmail.com       email
# 703            cosicadam0+tennisexpress.com@gmail.co       email
# ...                                              ...         ...
# 40973                 cosicadam0+rapyd.net@gmail.com       email
# 41006             cosicadam0+mediavoice.com@gmail.co       email
# 41010           cosicadam0+codeavengers.com@gmail.co       email
# 41090       cosicadam0+atlantisbahamas.com@gmail.com       email
# 41214           cosicadam0+thenewsstar.com@gmail.com       email
#
#                   encoding   leak_type                              final_url  \
# 0                unencoded  post_leaks               https://www.houston.org/
# 478              urlencode   url_leaks                  https://www.bruna.nl/
# 495                 sha256   url_leaks  https://www.democratandchronicle.com/
# 618                 sha256   url_leaks   https://www.burlingtonfreepress.com/
# 703              urlencode   url_leaks         https://www.tennisexpress.com/
# ...                    ...         ...                                    ...
# 40973  urlencode-urlencode   url_leaks                 https://www.rapyd.net/
# 41006               base64   url_leaks   https://mediavoice.com/login/?next=/
# 41010            urlencode  post_leaks          https://www.codeavengers.com/
# 41090               base64   url_leaks       https://www.atlantisbahamas.com/
# 41214               sha256   url_leaks           https://www.thenewsstar.com/
#
#                final_url_domain               initial_url  \
# 0                   houston.org               houston.org
# 478                    bruna.nl                  bruna.nl
# 495    democratandchronicle.com  democratandchronicle.com
# 618     burlingtonfreepress.com   burlingtonfreepress.com
# 703           tennisexpress.com         tennisexpress.com
# ...                         ...                       ...
# 40973                 rapyd.net                 rapyd.net
# 41006            mediavoice.com            mediavoice.com
# 41010          codeavengers.com          codeavengers.com
# 41090       atlantisbahamas.com       atlantisbahamas.com
# 41214           thenewsstar.com           thenewsstar.com
#
#                    initial_hostname          last_page_domain  \
# 0                   www.houston.org               houston.org
# 478                    www.bruna.nl                  bruna.nl
# 495    www.democratandchronicle.com  democratandchronicle.com
# 618     www.burlingtonfreepress.com   burlingtonfreepress.com
# 703           www.tennisexpress.com         tennisexpress.com
# ...                             ...                       ...
# 40973                 www.rapyd.net                 rapyd.net
# 41006                mediavoice.com            mediavoice.com
# 41010          www.codeavengers.com          codeavengers.com
# 41090       www.atlantisbahamas.com       atlantisbahamas.com
# 41214           www.thenewsstar.com           thenewsstar.com
#
#                                              request_url  ...  \
# 0      https://r.lr-ingest.io/i?a=hou67o%2Fghp-client...  ...
# 478    https://tr.datatrics.com/?action_name=Online%2...  ...
# 495    https://trc.taboola.com/sg/tfa-eid/1/um/?uils=...  ...
# 618    https://trc.taboola.com/sg/tfa-eid/1/um/?uils=...  ...
# 703    https://sca1.listrakbi.com/2wZX5FvW1Fkg/cart/f...  ...
# ...                                                  ...  ...
# 40973  https://d.adroll.com/emailc/5NQSP5JB7ZH2XGXJDA...  ...
# 41006  https://hn.inspectlet.com/pdata?d=cinmi,12136,...  ...
# 41010     https://track-v2.funnelytics.io/set-attributes  ...
# 41090  https://shopper.shop.pe/pixel.png?info=eyJlbWF...  ...
# 41214  https://trc.taboola.com/sg/tfa-eid/1/um/?uils=...  ...
#
#       is_req_off_site_direction  req_domain_entity    sniff_initiators  \
# 0                         False                NaN               set()
# 478                       False                NaN               set()
# 495                       False      Taboola, Inc.               set()
# 618                       False      Taboola, Inc.     {'taboola.com'}
# 703                       False            Listrak               set()
# ...                         ...                ...                 ...
# 40973                     False       AdRoll, Inc.               set()
# 41006                     False         Inspectlet  {'inspectlet.com'}
# 41010                     False                NaN               set()
# 41090                     False       Add Shoppers               set()
# 41214                     False      Taboola, Inc.               set()
#
#        is_req_domain_among_sniff_initiators  ublock_blocked  tds_blocked  \
# 0                                     False            True        False
# 478                                   False            True        False
# 495                                   False            True         True
# 618                                    True            True         True
# 703                                   False            True         True
# ...                                     ...             ...          ...
# 40973                                 False            True         True
# 41006                                  True            True        False
# 41010                                 False           False        False
# 41090                                 False            True        False
# 41214                                 False            True         True
#
#        ends_with_c ends_with_co  cname  \
# 0            False        False  False
# 478           True        False  False
# 495          False        False  False
# 618          False        False  False
# 703          False         True  False
# ...            ...          ...    ...
# 40973        False        False  False
# 41006        False         True  False
# 41010        False         True  False
# 41090        False        False  False
# 41214        False        False  False
#
#                                      req_domain_category
# 0                                                    NaN
# 478                                                  NaN
# 495    Third-Party Analytics Marketing, Audience Meas...
# 618    Third-Party Analytics Marketing, Audience Meas...
# 703           Analytics, Third-Party Analytics Marketing
# ...                                                  ...
# 40973                 Advertising, Ad Motivated Tracking
# 41006    Third-Party Analytics Marketing, Session Replay
# 41010                                                NaN
# 41090                                                NaN
# 41214  Third-Party Analytics Marketing, Audience Meas...
#
# [261 rows x 48 columns]

# %% [markdown]
# # Categories

# %%
categories_100K_final_dict = defaultdict(int)
for site_url, category in sites_categories.items():
    splitted_category = category.strip().split(', ')
    for each_category in splitted_category:
        categories_100K_final_dict[each_category] += 1

# %%
log_details['initial_hostname']
filled_sites = set(log_details['initial_hostname'])
log_details['initial_url'] = log_details.apply (lambda row: get_domain('http://' + row['initial_hostname']), axis=1)
categories_filled_final_dict = defaultdict(int)
filled_sites_domain_set = set(log_details.initial_url)
for site_url, category in sites_categories.items():
    if site_url in filled_sites_domain_set:
        splitted_category = category.strip().split(', ')
        for each_category in splitted_category:
            categories_filled_final_dict[each_category] += 1

# %%
unique_email_sites_df = unique_tracking_related_df[unique_tracking_related_df.search_type=='email'].drop_duplicates('initial_hostname')
leaky_categories_dict = defaultdict(int)
for index, row in unique_email_sites_df.iterrows():
    splitted_category = row['category'].strip().split(', ')
#     print(row)
    for each_category in splitted_category:
        leaky_categories_dict[each_category] += 1

# %%
category_dict = dict()
tuples = []
for category, value in categories_100K_final_dict.items():
    filled_num = 0
    leaky_num = 0
    total_num = value
    if category in categories_filled_final_dict.keys():
        filled_num = categories_filled_final_dict[category]
    if category in leaky_categories_dict.keys():
        leaky_num = leaky_categories_dict[category]
    tuple_el = (category, total_num, filled_num, leaky_num)
    tuples.append(tuple_el)

# %%
categories_final = pd.DataFrame(tuples, columns=['category', 'total', 'filled', 'leaky']) 
categories_final['percentage'] = categories_final['leaky'] *100/ categories_final['filled']
categories_final['percentage'].astype(float).round(1)
categories_filtered = categories_final[categories_final.total>1000].sort_values(by='percentage', ascending=False)
categories_filtered['percentage'] = categories_filtered['percentage'].astype(float).round(1)
len(categories_filtered),categories_filtered
# Out:
# (23,
#                       category  total  filled  leaky  percentage
#  53             Fashion/Beauty   1669    1179    224        19.0
#  7             Online Shopping   5395    3744    567        15.1
#  64         Recreation/Hobbies   1098     760     95        12.5
#  18               General News   7390    3848    392        10.2
#  6                  Blogs/Wiki   5415    3055    237         7.8
#  4                    Business  13462    7924    484         6.1
#  22    Marketing/Merchandising   4964    3218    192         6.0
#  39                     Travel   2519    1379     82         5.9
#  5           Software/Hardware   4933    2855    162         5.7
#  38                     Sports   1910    1002     56         5.6
#  26                     Health   2516    1439     69         4.8
#  16          Internet Services   7974    4671    199         4.3
#  12              Entertainment   5297    2619     98         3.7
#  23            Finance/Banking   3699    1518     49         3.2
#  10        Education/Reference  10190    4432    133         3.0
#  8                Portal Sites   1544     694     19         2.7
#  40         Public Information   2346    1084     27         2.5
#  17  Technical/Business Forums   1297     734     17         2.3
#  25                      Games   2173     896     11         1.2
#  33    Non-Profit/Advocacy/NGO   2713    1866     22         1.2
#  21        Government/Military   3754     974      7         0.7
#  19              Uncategorized   1616     646      2         0.3
#  30                Pornography   1388     534      0         0.0)

# %% [markdown]
# ## Leaks on sites where CMP detected

# %%
len(tracker_related_reqs_df[tracker_related_reqs_df.was_cmp_detected].drop_duplicates('initial_hostname'))
# Out:
# 228

# %% [markdown]
# ## Is req domain among the sniff initiators?

# %%
not_in_sniff_inits = set(unique_email_leaks[~unique_email_leaks.is_req_domain_among_sniff_initiators].drop_duplicates('initial_hostname').initial_hostname)
in_sniff_inits = set(unique_email_leaks[unique_email_leaks.is_req_domain_among_sniff_initiators].drop_duplicates('initial_hostname').initial_hostname)
len(not_in_sniff_inits.difference(in_sniff_inits)), len(not_in_sniff_inits), len(in_sniff_inits), len(unique_email_leaks.drop_duplicates('initial_hostname'))
# Out:
# (1639, 1762, 1311, 2950)

# %%
unique_tracking_related_df.leak_type.value_counts()
# Out:
# url_leaks     11389
# post_leaks     1358
# Name: leak_type, dtype: int64

# %% [markdown]
# # HTTP WEB SOCKET

# %%
unique_email_leaks['starts_with_wss'] = list(
    map(lambda x: x.startswith('wss'), unique_email_leaks['request_url']))
# Out:
# <ipython-input-32-afa97f9c504f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_email_leaks['starts_with_wss'] = list(

# %%
unique_email_leaks[unique_email_leaks.starts_with_wss].drop_duplicates('request_url_domain')
# Out:
#                                     search search_type   encoding   leak_type  \
# 66          cosicadam0+omaha.com@gmail.com       email  unencoded  post_leaks
# 2222  cosicadam0+menlosecurity.com@gmail.c       email  urlencode  post_leaks
# 2302        cosicadam0+fully.com@gmail.com       email     sha256  post_leaks
# 9907      cosicadam0+trivago.co.uk@gmail.c       email  unencoded  post_leaks
#
#                            final_url   final_url_domain        initial_url  \
# 66                https://omaha.com/          omaha.com          omaha.com
# 2222  https://www.menlosecurity.com/  menlosecurity.com  menlosecurity.com
# 2302          https://www.fully.com/          fully.com          fully.com
# 9907      https://www.trivago.co.uk/      trivago.co.uk      trivago.co.uk
#
#            initial_hostname   last_page_domain  \
# 66                omaha.com          omaha.com
# 2222  www.menlosecurity.com  menlosecurity.com
# 2302          www.fully.com          fully.com
# 9907      www.trivago.co.uk      trivago.co.uk
#
#                                           request_url  ... req_domain_entity  \
# 66                       wss://am.freshrelevance.com/  ...               NaN
# 2222           wss://ws10.hotjar.com/api/v2/client/ws  ...               NaN
# 2302                    wss://input.noibu.com/pv_part  ...               NaN
# 9907  wss://collection.decibelinsight.net/i/13786/ws/  ...               NaN
#
#                                        sniff_initiators  \
# 66                                                set()
# 2222                      {'marketo.com', 'hotjar.com'}
# 2302  {'noibu.com', 'rejoiner.com', 'fully.com', 'js...
# 9907                                              set()
#
#       is_req_domain_among_sniff_initiators  ublock_blocked  tds_blocked  \
# 66                                   False           False        False
# 2222                                 False            True         True
# 2302                                 False            True        False
# 9907                                 False            True        False
#
#       ends_with_c  ends_with_co  cname                   req_domain_category  \
# 66          False         False  False                                   NaN
# 2222         True         False  False  Audience Measurement, Session Replay
# 2302        False         False  False                                   NaN
# 9907         True         False  False                                   NaN
#
#       starts_with_wss
# 66               True
# 2222             True
# 2302             True
# 9907             True
#
# [4 rows x 49 columns]

# %%
unique_email_leaks['starts_with_http'] = list(
    map(lambda x: x.startswith('http:'), unique_email_leaks['request_url'])) 

unique_email_leaks[unique_email_leaks.starts_with_http].drop_duplicates('initial_hostname')
# Out:
# <ipython-input-34-03bdf40e02da>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_email_leaks['starts_with_http'] = list(
#                                               search search_type  \
# 753                  cosicadam0+onfido.com@gmail.com       email
# 1704   cosicadam0+actionforhealthykids.org@gmail.com       email
# 4372         cosicadam0+pressgazette.co.uk@gmail.com       email
# 9214                   cosicadam0+iiba.org@gmail.com       email
# 9420                  cosicadam0+ctbuh.org@gmail.com       email
# 10033      cosicadam0+skyscrapercenter.com@gmail.com       email
# 17923                 cosicadam0+avoxi.com@gmail.com       email
# 18774               cosicadam0+ashland.com@gmail.com       email
# 21373              cosicadam0+adcolony.com@gmail.com       email
# 26054               cosicadam0+eastern.edu@gmail.com       email
# 28679       cosicadam0+complyadvantage.com@gmail.com       email
# 38687  cosicadam0+advertisers.contobox.com@gmail.com       email
# 38689           cosicadam0+ntrepidcorp.com@gmail.com       email
# 39819       cosicadam0+affiliatesummit.com@gmail.com       email
#
#                   encoding  leak_type                              final_url  \
# 753    urlencode-urlencode  url_leaks                    https://onfido.com/
# 1704   urlencode-urlencode  url_leaks  https://www.actionforhealthykids.org/
# 4372   urlencode-urlencode  url_leaks            https://pressgazette.co.uk/
# 9214   urlencode-urlencode  url_leaks                  https://www.iiba.org/
# 9420   urlencode-urlencode  url_leaks                 https://www.ctbuh.org/
# 10033  urlencode-urlencode  url_leaks   https://www.ctbuh.org/?redirect=true
# 17923  urlencode-urlencode  url_leaks                 https://www.avoxi.com/
# 18774  urlencode-urlencode  url_leaks               https://www.ashland.com/
# 21373  urlencode-urlencode  url_leaks              https://www.adcolony.com/
# 26054  urlencode-urlencode  url_leaks               https://www.eastern.edu/
# 28679  urlencode-urlencode  url_leaks           https://complyadvantage.com/
# 38687  urlencode-urlencode  url_leaks  https://www.advertisers.contobox.com/
# 38689  urlencode-urlencode  url_leaks               https://ntrepidcorp.com/
# 39819  urlencode-urlencode  url_leaks       https://www.affiliatesummit.com/
#
#                final_url_domain               initial_url  \
# 753                  onfido.com                onfido.com
# 1704   actionforhealthykids.org  actionforhealthykids.org
# 4372         pressgazette.co.uk        pressgazette.co.uk
# 9214                   iiba.org                  iiba.org
# 9420                  ctbuh.org                 ctbuh.org
# 10033                 ctbuh.org      skyscrapercenter.com
# 17923                 avoxi.com                 avoxi.com
# 18774               ashland.com               ashland.com
# 21373              adcolony.com              adcolony.com
# 26054               eastern.edu               eastern.edu
# 28679       complyadvantage.com       complyadvantage.com
# 38687              contobox.com              contobox.com
# 38689           ntrepidcorp.com           ntrepidcorp.com
# 39819       affiliatesummit.com       affiliatesummit.com
#
#                    initial_hostname          last_page_domain  \
# 753                      onfido.com                onfido.com
# 1704   www.actionforhealthykids.org  actionforhealthykids.org
# 4372             pressgazette.co.uk        pressgazette.co.uk
# 9214                   www.iiba.org                  iiba.org
# 9420                  www.ctbuh.org                 ctbuh.org
# 10033      www.skyscrapercenter.com                 ctbuh.org
# 17923                 www.avoxi.com                 avoxi.com
# 18774               www.ashland.com               ashland.com
# 21373              www.adcolony.com              adcolony.com
# 26054               www.eastern.edu               eastern.edu
# 28679           complyadvantage.com       complyadvantage.com
# 38687  www.advertisers.contobox.com              contobox.com
# 38689               ntrepidcorp.com           ntrepidcorp.com
# 39819       www.affiliatesummit.com       affiliatesummit.com
#
#                                              request_url  ...  \
# 753    http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 1704   http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 4372   http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 9214   http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 9420   http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 10033  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 17923  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 18774  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 21373  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 26054  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 28679  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 38687  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 38689  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 39819  http://go.pardot.com/form/checkEmailAjax/accou...  ...
#
#                      sniff_initiators  is_req_domain_among_sniff_initiators  \
# 753                    {'onfido.com'}                                 False
# 1704     {'actionforhealthykids.org'}                                 False
# 4372           {'pressgazette.co.uk'}                                 False
# 9214                            set()                                 False
# 9420                    {'ctbuh.org'}                                 False
# 10033                   {'ctbuh.org'}                                 False
# 17923    {'avoxi.com', 'bizible.com'}                                 False
# 18774  {'ashland.com', 'gstatic.com'}                                 False
# 21373                {'adcolony.com'}                                 False
# 26054                 {'eastern.edu'}                                 False
# 28679         {'complyadvantage.com'}                                 False
# 38687                {'contobox.com'}                                 False
# 38689             {'ntrepidcorp.com'}                                 False
# 39819         {'affiliatesummit.com'}                                 False
#
#        ublock_blocked  tds_blocked  ends_with_c  ends_with_co  cname  \
# 753              True         True        False         False  False
# 1704             True         True        False         False  False
# 4372             True         True        False         False  False
# 9214             True         True        False         False  False
# 9420             True         True        False         False  False
# 10033            True         True        False         False  False
# 17923            True         True        False         False  False
# 18774            True         True        False         False  False
# 21373            True         True        False         False  False
# 26054            True         True        False         False  False
# 28679            True         True        False         False  False
# 38687            True         True        False         False  False
# 38689            True         True        False         False  False
# 39819            True         True        False         False  False
#
#                req_domain_category  starts_with_wss  starts_with_http
# 753    Analytics, Embedded Content            False              True
# 1704   Analytics, Embedded Content            False              True
# 4372   Analytics, Embedded Content            False              True
# 9214   Analytics, Embedded Content            False              True
# 9420   Analytics, Embedded Content            False              True
# 10033  Analytics, Embedded Content            False              True
# 17923  Analytics, Embedded Content            False              True
# 18774  Analytics, Embedded Content            False              True
# 21373  Analytics, Embedded Content            False              True
# 26054  Analytics, Embedded Content            False              True
# 28679  Analytics, Embedded Content            False              True
# 38687  Analytics, Embedded Content            False              True
# 38689  Analytics, Embedded Content            False              True
# 39819  Analytics, Embedded Content            False              True
#
# [14 rows x 50 columns]
