# %%
import pandas as pd
import pickle
from collections import defaultdict
from leak_common import get_domain, find_prominence
import matplotlib.pyplot as plt

# %%
with open('extra_tracker_domains.pkl', 'rb') as handle:
    extra_tracker_domains = pickle.load(handle)

# %% [markdown]
# # Read from pickles

# %%
log_details = pd.read_pickle("../../nyc_mobile_log_details.pkl")
df = pd.read_csv("mobile_no_action_nyc_crawl.csv", sep='\t', encoding='utf-8')
# Due to copyright restrictions, we can't share categories info
# with open('../pkls_csvs/categories.pkl', 'rb') as handle:
#     sites_categories = pickle.load(handle)

# %% [markdown]
# # Additional Columns

# %%
df['is_blocked'] = df.easy_list_blocked | df.easy_privacy_blocked | df.disconnect_blocked | df.whotracksme_blocked | (df.tds_blocked) | (df.ublock_blocked) | (df.request_url_domain.isin(extra_tracker_domains))

# %%
df['tracker_related'] = df.third_party_req & df.is_blocked

# %% [markdown]
# # All Requests

# %%
all_reqs = df
unique_all_reqs = all_reqs.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'])
all_reqs_email = all_reqs[all_reqs.search_type == 'email']
unique_all_reqs_email = all_reqs_email.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'])

# %%
print('all_reqs: ', len(all_reqs))
print('unique_all_reqs: ', len(unique_all_reqs))
print('all_reqs_email: ', len(all_reqs_email))
print('unique_all_reqs_email: ', len(unique_all_reqs_email))
# Out:
# all_reqs:  26073
# unique_all_reqs:  11155
# all_reqs_email:  23242
# unique_all_reqs_email:  9792

# %% [markdown]
# # Third Party Requests

# %%
third_party_reqs = df[df.third_party_req & ~df.is_req_off_site_direction]
unique_third_party_reqs = third_party_reqs.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'])
third_party_reqs_email = third_party_reqs[third_party_reqs.search_type == 'email']
unique_third_party_reqs_email = third_party_reqs_email.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'])

# %%
print('third_party_reqs: ', len(third_party_reqs))
print('unique_third_party_reqs: ', len(unique_third_party_reqs))
print('third_party_reqs_email: ', len(third_party_reqs_email))
print('unique_third_party_reqs_email: ', len(unique_third_party_reqs_email))
# Out:
# third_party_reqs:  17112
# unique_third_party_reqs:  8021
# third_party_reqs_email:  16678
# unique_third_party_reqs_email:  7854

# %% [markdown]
# # Tracking Related Requests

# %%
tracker_related_reqs_df = df[~df.is_req_off_site_direction & (df.leak_type!='response_cookie_leaks') & (df.leak_type!='response_location_leaks') &(df.tracker_related) & ((df.final_url_domain == df.last_page_domain) | (df.initial_url == df.last_page_domain))]
unique_tracking_related_df = tracker_related_reqs_df.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'],keep='last')
email_leaks = tracker_related_reqs_df[tracker_related_reqs_df.search_type == 'email']
unique_email_leaks = email_leaks.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'])

# %%
print('tracker_related_reqs_df: ', len(tracker_related_reqs_df))
print('unique_tracking_related_df: ', len(unique_tracking_related_df))
print('email_leaks: ', len(email_leaks))
print('unique_email_leaks: ', len(unique_email_leaks))
# Out:
# tracker_related_reqs_df:  12115
# unique_tracking_related_df:  6569
# email_leaks:  11804
# unique_email_leaks:  6466

# %% [markdown]
# # High Level Statistics

# %%
print('Distinct websites where emails are leaked to both 1st, 3rd parties and tracker domains: ',len(all_reqs_email.drop_duplicates('initial_hostname')))
print('Distinct websites where emails are leaked to both 3rd parties and tracker domains: ',len(unique_third_party_reqs_email.drop_duplicates('initial_hostname')))
print('Distinct websites where emails are leaked to only tracker domains: ',len(unique_email_leaks.drop_duplicates('initial_hostname')))
# Out:
# Distinct websites where emails are leaked to both 1st, 3rd parties and tracker domains:  5126
# Distinct websites where emails are leaked to both 3rd parties and tracker domains:  3513
# Distinct websites where emails are leaked to only tracker domains:  2744

# %% [markdown]
# # Prominence

# %%
prominence_list = find_prominence(unique_tracking_related_df[unique_tracking_related_df.search_type=='email'])

# %%
prominence_df = pd.DataFrame(prominence_list, columns=['domain','prominence', 'number_of_sites'])

# %%
prominence_df.sort_values('prominence',ascending=False).head(20)
# Out:
#                 domain  prominence  number_of_sites
# 3            rlcdn.com    0.044991              404
# 11         taboola.com    0.039607              335
# 18         bizible.com    0.020878              172
# 5          bouncex.net    0.017625              182
# 1        fullstory.com    0.011590              235
# 6           zenaps.com    0.009820              115
# 7            awin1.com    0.009797              114
# 4            yahoo.com    0.007354              266
# 2            yandex.ru    0.005454              120
# 33          adroll.com    0.004921              122
# 22       salecycle.com    0.003976               47
# 19        smarterhq.io    0.003966               28
# 14             shop.pe    0.003720               94
# 12    securedvisit.com    0.003672               70
# 68  glassboxdigital.io    0.003502                6
# 8   freshrelevance.com    0.003147               72
# 41          bronto.com    0.002500               90
# 0        listrakbi.com    0.002333              103
# 67          pippio.com    0.002173               11
# 39        gravatar.com    0.001795               41

# %% [markdown]
# ## Leak types

# %%
unique_tracking_related_df.leak_type.value_counts()
# Out:
# url_leaks     5339
# post_leaks    1230
# Name: leak_type, dtype: int64

# %% [markdown]
# ## Email leaks

# %%
unique_email_leaks[unique_email_leaks['rank_of_site']<2000].drop_duplicates('initial_url').sort_values('rank_of_site')[['initial_url', 'rank_of_site']].head(12)
# Out:
#                 initial_url  rank_of_site
# 647               issuu.com            95
# 24210          usatoday.com           154
# 4595               time.com           191
# 2343              udemy.com           196
# 17538        healthline.com           217
# 10398           foxnews.com           234
# 3645            zendesk.com           239
# 9804              webmd.com           288
# 4087            shopify.com           300
# 3300           marriott.com           328
# 24440  medicalnewstoday.com           525
# 16619          newsweek.com           567

# %%
distinct_websites_email_leaks = unique_email_leaks.drop_duplicates('initial_hostname')

# %%
unique_email_leaks.encoding.value_counts()
# Out:
# sha256                          1110
# urlencode-sha256                1065
# unencoded                        824
# urlencode                        597
# md5                              468
# urlencode-md5                    401
# sha1                             260
# urlencode-sha1                   247
# base64                           235
# sha_salted_1                     229
# urlencode-sha_salted_1           229
# urlencode-base64                 192
# lzstring-urlencode               187
# urlencode-lzstring-urlencode     186
# urlencode-urlencode              151
# urlencode-custom_map_1            78
# urlencode-sha512                   2
# sha512                             2
# base64-base64                      1
# base64-sha256                      1
# base64-sha1                        1
# Name: encoding, dtype: int64

# %% [markdown]
# ## Tracked But NOT Sniffed

# %%
email_leaks[email_leaks.email_sniffed==False].drop_duplicates('initial_hostname')
# Out:
#                                      search search_type  \
# 3          cosiceve0+tirebuyer.com@gmail.co       email
# 31     cosiceve0+allaboutjazz.com@gmail.com       email
# 172        cosiceve0+vivaterra.com@gmail.co       email
# 252           cosiceve0+aurea.com@gmail.com       email
# 275      cosiceve0+on-running.com@gmail.com       email
# ...                                     ...         ...
# 25530      cosiceve0+megabonus.com@gmail.co       email
# 25575            cosiceve0+bruna.nl@gmail.c       email
# 25633     cosiceve0+protective.com@gmail.co       email
# 25780            cosiceve0+ripl.com@gmail.c       email
# 26039   cosiceve0+topodesigns.com@gmail.com       email
#
#                      encoding   leak_type  \
# 3                   urlencode   url_leaks
# 31           urlencode-sha256   url_leaks
# 172    urlencode-custom_map_1   url_leaks
# 252                 urlencode   url_leaks
# 275        lzstring-urlencode   url_leaks
# ...                       ...         ...
# 25530               unencoded  post_leaks
# 25575               urlencode   url_leaks
# 25633               unencoded  post_leaks
# 25780               urlencode   url_leaks
# 26039               urlencode   url_leaks
#
#                                                final_url  final_url_domain  \
# 3                             https://www.tirebuyer.com/     tirebuyer.com
# 31     https://www.allaboutjazz.com/index.php?&width=412  allaboutjazz.com
# 172                           https://www.vivaterra.com/     vivaterra.com
# 252                               https://www.aurea.com/         aurea.com
# 275                    https://www.on-running.com/en-us/    on-running.com
# ...                                                  ...               ...
# 25530                             https://megabonus.com/     megabonus.com
# 25575                              https://www.bruna.nl/          bruna.nl
# 25633                        https://www.protective.com/    protective.com
# 25780                              https://www.ripl.com/          ripl.com
# 26039                           https://topodesigns.com/   topodesigns.com
#
#             initial_url      initial_hostname  last_page_domain  \
# 3         tirebuyer.com     www.tirebuyer.com     tirebuyer.com
# 31     allaboutjazz.com  www.allaboutjazz.com  allaboutjazz.com
# 172       vivaterra.com     www.vivaterra.com     vivaterra.com
# 252           aurea.com         www.aurea.com         aurea.com
# 275      on-running.com    www.on-running.com    on-running.com
# ...                 ...                   ...               ...
# 25530     megabonus.com         megabonus.com     megabonus.com
# 25575          bruna.nl          www.bruna.nl          bruna.nl
# 25633    protective.com    www.protective.com    protective.com
# 25780          ripl.com          www.ripl.com          ripl.com
# 26039   topodesigns.com       topodesigns.com   topodesigns.com
#
#                                              request_url  ... tracker_related  \
# 3      https://sca1.listrakbi.com/hWEdiEkwhcns/cart/f...  ...            True
# 31     https://api.rlcdn.com/api/identity/envelope?pi...  ...            True
# 172    https://track.securedvisit.com/citecapture/?cc...  ...            True
# 252    https://cdn.bizible.com/m/blr?e=OMFbqazoSXRsTs...  ...            True
# 275    https://events.bouncex.net/track.gif/user?wklz...  ...            True
# ...                                                  ...  ...             ...
# 25530  https://mc.yandex.ru/webvisor/37456880?wmode=0...  ...            True
# 25575  https://tr.datatrics.com/?action_name=Online%2...  ...            True
# 25633  https://rs.fullstory.com/rec/bundle?OrgId=TSE6...  ...            True
# 25780  https://www.upsellit.com/hound/saveData.jsp?si...  ...            True
# 26039  https://sca1.listrakbi.com/oJa2HYi6vkIz/cart/f...  ...            True
#
#                                                    xpath                   id  \
# 3                        $x("//*[@id='ltkpopup-email']")       ltkpopup-email
# 31     $x("//*[@id='section-subscribe']/div/div/div/d...                  NaN
# 172    $x("//*[@id='footer']/div[2]/div[1]/div/div[2]...                  NaN
# 252                               $x("//*[@id='Email']")                Email
# 275                               $x("//*[@id='email']")                email
# ...                                                  ...                  ...
# 25530                $x("//*[@id='auth-form-password']")   auth-form-password
# 25575                        $x("//*[@id='newsletter']")           newsletter
# 25633                          $x("//*[@id='password']")             password
# 25780               $x("//*[@id='input_comp-k9zv53du']")  input_comp-k9zv53du
# 26039                    $x("//*[@id='ltkpopup-email']")       ltkpopup-email
#
#                                               latest_url  \
# 3                             https://www.tirebuyer.com/
# 31     https://www.allaboutjazz.com/index.php?&width=412
# 172                           https://www.vivaterra.com/
# 252          https://content.aurea.com/worx-registration
# 275                    https://www.on-running.com/en-us/
# ...                                                  ...
# 25530  https://auth.megabonus.com/?redirect_url=https...
# 25575                              https://www.bruna.nl/
# 25633             https://myaccount.protective.com/login
# 25780                              https://www.ripl.com/
# 26039                           https://topodesigns.com/
#
#        last_page_domain_iframe  is_req_off_site_direction  req_type  \
# 3                tirebuyer.com                      False     Image
# 31            allaboutjazz.com                      False     Fetch
# 172              vivaterra.com                      False    Script
# 252                  aurea.com                      False     Image
# 275             on-running.com                      False     Image
# ...                        ...                        ...       ...
# 25530            megabonus.com                      False       XHR
# 25575                 bruna.nl                      False     Image
# 25633           protective.com                      False       XHR
# 25780                 ripl.com                      False    Script
# 26039          topodesigns.com                      False     Image
#
#       ublock_blocked  tds_blocked  \
# 3               True         True
# 31              True         True
# 172             True         True
# 252             True        False
# 275             True        False
# ...              ...          ...
# 25530           True         True
# 25575           True        False
# 25633           True         True
# 25780           True        False
# 26039           True         True
#
#                                 req_domain_category
# 3                Ad Motivated Tracking, Advertising
# 31               Ad Motivated Tracking, Advertising
# 172              Ad Motivated Tracking, Advertising
# 252    Analytics and Tracking, Marketing Automation
# 275                                             NaN
# ...                                             ...
# 25530            Ad Motivated Tracking, Advertising
# 25575       Analytics and Tracking, Personalization
# 25633                     Session Replay, Analytics
# 25780      Analytics and Tracking, Cart Abandonment
# 26039            Ad Motivated Tracking, Advertising
#
# [178 rows x 41 columns]

# %% [markdown]
# # Categories

# %%
categories_100K_final_dict = defaultdict(int)
for site_url, category in sites_categories.items():
    splitted_category = category.strip().split(', ')
    for each_category in splitted_category:
        categories_100K_final_dict[each_category] += 1

# %%
log_details['initial_hostname']
filled_sites = set(log_details['initial_hostname'])
log_details['initial_url'] = log_details.apply (lambda row: get_domain('http://' + row['initial_hostname']), axis=1)
categories_filled_final_dict = defaultdict(int)
filled_sites_domain_set = set(log_details.initial_url)
for site_url, category in sites_categories.items():
    if site_url in filled_sites_domain_set:
        splitted_category = category.strip().split(', ')
        for each_category in splitted_category:
            categories_filled_final_dict[each_category] += 1

# %%
unique_email_sites_df = unique_tracking_related_df[unique_tracking_related_df.search_type=='email'].drop_duplicates('initial_hostname')
leaky_categories_dict = defaultdict(int)
for index, row in unique_email_sites_df.iterrows():
    splitted_category = sites_categories[row['initial_url']].strip().split(', ')
#     print(row)
    for each_category in splitted_category:
        leaky_categories_dict[each_category] += 1

# %%
category_dict = dict()
tuples = []
for category, value in categories_100K_final_dict.items():
    filled_num = 0
    leaky_num = 0
    total_num = value
    if category in categories_filled_final_dict.keys():
        filled_num = categories_filled_final_dict[category]
    if category in leaky_categories_dict.keys():
        leaky_num = leaky_categories_dict[category]
    tuple_el = (category, total_num, filled_num, leaky_num)
    tuples.append(tuple_el)

# %%
categories_final = pd.DataFrame(tuples, columns=['category', 'total', 'filled', 'leaky']) 
categories_final['percentage'] = categories_final['leaky'] *100/ categories_final['filled']
categories_final['percentage'].astype(float).round(1)
categories_filtered = categories_final[categories_final.total>1000].sort_values(by='percentage', ascending=False)
categories_filtered['percentage'] = categories_filtered['percentage'].astype(float).round(1)
len(categories_filtered),categories_filtered
# Out:
# (23,
#                       category  total  filled  leaky  percentage
#  53             Fashion/Beauty   1669    1305    219        16.8
#  7             Online Shopping   5395    3977    529        13.3
#  64         Recreation/Hobbies   1098     753     97        12.9
#  18               General News   7390    3832    378         9.9
#  6                  Blogs/Wiki   5415    3140    236         7.5
#  22    Marketing/Merchandising   4964    3275    180         5.5
#  4                    Business  13462    8295    434         5.2
#  5           Software/Hardware   4933    2932    148         5.0
#  39                     Travel   2519    1464     69         4.7
#  38                     Sports   1910    1094     50         4.6
#  16          Internet Services   7974    5063    182         3.6
#  12              Entertainment   5297    2686     95         3.5
#  26                     Health   2516    1553     52         3.3
#  23            Finance/Banking   3699    2056     56         2.7
#  40         Public Information   2346    1120     26         2.3
#  17  Technical/Business Forums   1297     737     17         2.3
#  8                Portal Sites   1544     765     15         2.0
#  10        Education/Reference  10190    5850    107         1.8
#  33    Non-Profit/Advocacy/NGO   2713    1851     20         1.1
#  25                      Games   2173    1005     10         1.0
#  21        Government/Military   3754    1357      6         0.4
#  30                Pornography   1388     631      2         0.3
#  19              Uncategorized   1616     755      2         0.3)

# %% [markdown]
# ## Leaks on sites where CMP detected

# %%
len(tracker_related_reqs_df[tracker_related_reqs_df.was_cmp_detected].drop_duplicates('initial_hostname'))
# Out:
# 209

# %% [markdown]
# ## Leak types

# %%
unique_tracking_related_df.leak_type.value_counts()
# Out:
# url_leaks     5339
# post_leaks    1230
# Name: leak_type, dtype: int64

# %% [markdown]
# # HTTP WEB SOCKET

# %%
unique_email_leaks['starts_with_wss'] = list(
    map(lambda x: x.startswith('wss'), unique_email_leaks['request_url']))
# Out:
# <ipython-input-28-afa97f9c504f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_email_leaks['starts_with_wss'] = list(

# %%
unique_email_leaks[unique_email_leaks.starts_with_wss].drop_duplicates('request_url_domain')
# Out:
#                                        search search_type  \
# 77            cosiceve0+chopard.com@gmail.com       email
# 444         cosiceve0+bettercloud.com@gmail.c       email
# 1822       cosiceve0+verabradley.com@gmail.co       email
# 5528  cosiceve0+mercuryinsurance.com@gmail.co       email
#
#                     encoding   leak_type                          final_url  \
# 77                 unencoded  post_leaks      https://www.chopard.com/intl/
# 444                urlencode  post_leaks       https://www.bettercloud.com/
# 1822  urlencode-custom_map_1  post_leaks           https://verabradley.com/
# 5528               unencoded  post_leaks  https://www.mercuryinsurance.com/
#
#           final_url_domain           initial_url          initial_hostname  \
# 77             chopard.com           chopard.com           www.chopard.com
# 444        bettercloud.com       bettercloud.com       www.bettercloud.com
# 1822       verabradley.com       verabradley.com           verabradley.com
# 5528  mercuryinsurance.com  mercuryinsurance.com  www.mercuryinsurance.com
#
#           last_page_domain                                      request_url  \
# 77             chopard.com                     wss://am.freshrelevance.com/
# 444        bettercloud.com            wss://ws2.hotjar.com/api/v2/client/ws
# 1822       verabradley.com                    wss://input.noibu.com/pv_part
# 5528  mercuryinsurance.com  wss://collection.decibelinsight.net/i/13502/ws/
#
#       ...                            xpath              id  \
# 77    ...           $x("//*[@id='email']")           email
# 444   ...           $x("//*[@id='Email']")           Email
# 1822  ...           $x("//*[@id='Email']")           Email
# 5528  ...  $x("//*[@id='login-password']")  login-password
#
#                                              latest_url  \
# 77    https://www.chopard.com/intl/chopard_newslette...
# 444                        https://www.bettercloud.com/
# 1822                           https://verabradley.com/
# 5528  https://cp.mercuryinsurance.com/cas/login?serv...
#
#       last_page_domain_iframe  is_req_off_site_direction   req_type  \
# 77                chopard.com                      False  WebSocket
# 444           bettercloud.com                      False  WebSocket
# 1822          verabradley.com                      False  WebSocket
# 5528     mercuryinsurance.com                      False  WebSocket
#
#       ublock_blocked tds_blocked  \
# 77             False       False
# 444             True        True
# 1822            True       False
# 5528            True       False
#
#                                   req_domain_category  starts_with_wss
# 77    Analytics and Tracking, Conversion Optimization             True
# 444                         Session Replay, Analytics             True
# 1822                          Widgets, Error Tracking             True
# 5528                                              NaN             True
#
# [4 rows x 42 columns]

# %%
unique_email_leaks['starts_with_http'] = list(
    map(lambda x: x.startswith('http:'), unique_email_leaks['request_url'])) 

unique_email_leaks[unique_email_leaks.starts_with_http].drop_duplicates('initial_hostname')
# Out:
# <ipython-input-30-03bdf40e02da>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_email_leaks['starts_with_http'] = list(
#                                              search search_type  \
# 2697                 cosiceve0+onfido.com@gmail.com       email
# 3245         cosiceve0+pressgazette.co.uk@gmail.com       email
# 4180          cosiceve0+rating-widget.com@gmail.com       email
# 8043   cosiceve0+advertisers.contobox.com@gmail.com       email
# 8153                  cosiceve0+ctbuh.org@gmail.com       email
# 11107               cosiceve0+vendini.com@gmail.com       email
# 15757       cosiceve0+affiliatesummit.com@gmail.com       email
# 16036                  cosiceve0+iiba.org@gmail.com       email
# 19192      cosiceve0+skyscrapercenter.com@gmail.com       email
# 19781                 cosiceve0+avoxi.com@gmail.com       email
# 22007              cosiceve0+adcolony.com@gmail.com       email
# 23244       cosiceve0+complyadvantage.com@gmail.com       email
# 24941  cosiceve0+actionforhealthykids.org@gmail.com       email
#
#                   encoding  leak_type                              final_url  \
# 2697   urlencode-urlencode  url_leaks                    https://onfido.com/
# 3245   urlencode-urlencode  url_leaks            https://pressgazette.co.uk/
# 4180                base64  url_leaks              http://rating-widget.com/
# 8043   urlencode-urlencode  url_leaks  https://www.advertisers.contobox.com/
# 8153   urlencode-urlencode  url_leaks                 https://www.ctbuh.org/
# 11107  urlencode-urlencode  url_leaks                   https://vendini.com/
# 15757  urlencode-urlencode  url_leaks       https://www.affiliatesummit.com/
# 16036  urlencode-urlencode  url_leaks                  https://www.iiba.org/
# 19192  urlencode-urlencode  url_leaks   https://www.ctbuh.org/?redirect=true
# 19781  urlencode-urlencode  url_leaks                 https://www.avoxi.com/
# 22007  urlencode-urlencode  url_leaks              https://www.adcolony.com/
# 23244  urlencode-urlencode  url_leaks           https://complyadvantage.com/
# 24941  urlencode-urlencode  url_leaks  https://www.actionforhealthykids.org/
#
#                final_url_domain               initial_url  \
# 2697                 onfido.com                onfido.com
# 3245         pressgazette.co.uk        pressgazette.co.uk
# 4180          rating-widget.com         rating-widget.com
# 8043               contobox.com              contobox.com
# 8153                  ctbuh.org                 ctbuh.org
# 11107               vendini.com               vendini.com
# 15757       affiliatesummit.com       affiliatesummit.com
# 16036                  iiba.org                  iiba.org
# 19192                 ctbuh.org      skyscrapercenter.com
# 19781                 avoxi.com                 avoxi.com
# 22007              adcolony.com              adcolony.com
# 23244       complyadvantage.com       complyadvantage.com
# 24941  actionforhealthykids.org  actionforhealthykids.org
#
#                    initial_hostname          last_page_domain  \
# 2697                     onfido.com                onfido.com
# 3245             pressgazette.co.uk        pressgazette.co.uk
# 4180              rating-widget.com         rating-widget.com
# 8043   www.advertisers.contobox.com              contobox.com
# 8153                  www.ctbuh.org                 ctbuh.org
# 11107                   vendini.com               vendini.com
# 15757       www.affiliatesummit.com       affiliatesummit.com
# 16036                  www.iiba.org                  iiba.org
# 19192      www.skyscrapercenter.com                 ctbuh.org
# 19781                 www.avoxi.com                 avoxi.com
# 22007              www.adcolony.com              adcolony.com
# 23244           complyadvantage.com       complyadvantage.com
# 24941  www.actionforhealthykids.org  actionforhealthykids.org
#
#                                              request_url  ...  \
# 2697   http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 3245   http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 4180   http://hn.inspectlet.com/pdata?d=cinmi,18206,3...  ...
# 8043   http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 8153   http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 11107  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 15757  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 16036  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 19192  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 19781  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 22007  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 23244  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 24941  http://go.pardot.com/form/checkEmailAjax/accou...  ...
#
#                                   id  \
# 2697       885253_8614pi_885253_8614
# 3245   375012_527938pi_375012_527938
# 4180                             NaN
# 8043     764333_14369pi_764333_14369
# 8153       878592_4768pi_878592_4768
# 11107        814053_979pi_814053_979
# 15757  528152_120597pi_528152_120597
# 16036                  Emailpi_Email
# 19192      878592_4768pi_878592_4768
# 19781    673993_73068pi_673993_73068
# 22007  210152_121705pi_210152_121705
# 23244    352551_41923pi_352551_41923
# 24941    21152_136543pi_21152_136543
#
#                                               latest_url  \
# 2697      https://go.onfido.com/l/885253/2020-09-16/29g1
# 3245   https://go.pressgazette.co.uk/l/375012/2021-01...
# 4180                           http://rating-widget.com/
# 8043   https://www2.contobox.com/l/764333/2019-10-03/...
# 8153   https://marketing.ctbuh.org/l/878592/2020-08-2...
# 11107  https://www2.vendini.com/l/814053/2019-11-01/2...
# 15757  https://info.affiliatesummit.com/l/528152/2020...
# 16036  https://go.iiba.org/email-signup?utm_source=We...
# 19192  https://marketing.ctbuh.org/l/878592/2020-08-2...
# 19781  https://marketing.avoxi.com/l/673993/2020-08-1...
# 22007  https://go-pardot.adcolony.com/l/210152/2021-0...
# 23244  https://www2.complyadvantage.com/l/352551/2019...
# 24941  https://www2.actionforhealthykids.org/l/21152/...
#
#         last_page_domain_iframe  is_req_off_site_direction  req_type  \
# 2697                 onfido.com                      False       XHR
# 3245         pressgazette.co.uk                      False       XHR
# 4180          rating-widget.com                      False     Image
# 8043               contobox.com                      False       XHR
# 8153                  ctbuh.org                      False       XHR
# 11107               vendini.com                      False       XHR
# 15757       affiliatesummit.com                      False       XHR
# 16036                  iiba.org                      False       XHR
# 19192                 ctbuh.org                      False       XHR
# 19781                 avoxi.com                      False       XHR
# 22007              adcolony.com                      False       XHR
# 23244       complyadvantage.com                      False       XHR
# 24941  actionforhealthykids.org                      False       XHR
#
#        ublock_blocked  tds_blocked  \
# 2697             True         True
# 3245             True         True
# 4180             True        False
# 8043             True         True
# 8153             True         True
# 11107            True         True
# 15757            True         True
# 16036            True         True
# 19192            True         True
# 19781            True         True
# 22007            True         True
# 23244            True         True
# 24941            True         True
#
#                                    req_domain_category  starts_with_wss  \
# 2697                Ad Motivated Tracking, Advertising            False
# 3245                Ad Motivated Tracking, Advertising            False
# 4180   Third-Party Analytics Marketing, Session Replay            False
# 8043                Ad Motivated Tracking, Advertising            False
# 8153                Ad Motivated Tracking, Advertising            False
# 11107               Ad Motivated Tracking, Advertising            False
# 15757               Ad Motivated Tracking, Advertising            False
# 16036               Ad Motivated Tracking, Advertising            False
# 19192               Ad Motivated Tracking, Advertising            False
# 19781               Ad Motivated Tracking, Advertising            False
# 22007               Ad Motivated Tracking, Advertising            False
# 23244               Ad Motivated Tracking, Advertising            False
# 24941               Ad Motivated Tracking, Advertising            False
#
#        starts_with_http
# 2697               True
# 3245               True
# 4180               True
# 8043               True
# 8153               True
# 11107              True
# 15757              True
# 16036              True
# 19192              True
# 19781              True
# 22007              True
# 23244              True
# 24941              True
#
# [13 rows x 43 columns]
