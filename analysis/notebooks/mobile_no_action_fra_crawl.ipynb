# %%
import pandas as pd
import pickle
from collections import defaultdict
from leak_common import get_domain, find_prominence
import matplotlib.pyplot as plt

# %%
with open('../pkls_csvs/extra_tracker_domains.pkl', 'rb') as handle:
    extra_tracker_domains = pickle.load(handle)

# %% [markdown]
# # Read from pickles

# %%
log_details = pd.read_pickle("../pkls_csvs/fra_mobile_log_details.pkl")
df = pd.read_csv("../pkls_csvs/mobile_no_action_fra_crawl.csv", sep='\t', encoding='utf-8')
## Due to copyright restrictions, we can't share categories info
# with open('../pkls_csvs/categories.pkl', 'rb') as handle:
#     sites_categories = pickle.load(handle)

# %% [markdown]
# # Additional Columns

# %%
df['is_blocked'] = df.easy_list_blocked | df.easy_privacy_blocked | df.disconnect_blocked | df.whotracksme_blocked | (df.tds_blocked) | (df.ublock_blocked) | (df.request_url_domain.isin(extra_tracker_domains))

# %%
df['tracker_related'] = df.third_party_req & df.is_blocked

# %% [markdown]
# # All Requests

# %%
all_reqs = df
unique_all_reqs = all_reqs.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'])
all_reqs_email = all_reqs[all_reqs.search_type == 'email']
unique_all_reqs_email = all_reqs_email.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'])

# %%
print('all_reqs: ', len(all_reqs))
print('unique_all_reqs: ', len(unique_all_reqs))
print('all_reqs_email: ', len(all_reqs_email))
print('unique_all_reqs_email: ', len(unique_all_reqs_email))
# Out:
# all_reqs:  20706
# unique_all_reqs:  7392
# all_reqs_email:  17861
# unique_all_reqs_email:  6039

# %% [markdown]
# # Third Party Requests

# %%
third_party_reqs = df[df.third_party_req & ~df.is_req_off_site_direction]
unique_third_party_reqs = third_party_reqs.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'])
third_party_reqs_email = third_party_reqs[third_party_reqs.search_type == 'email']
unique_third_party_reqs_email = third_party_reqs_email.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'])

# %%
print('third_party_reqs: ', len(third_party_reqs))
print('unique_third_party_reqs: ', len(unique_third_party_reqs))
print('third_party_reqs_email: ', len(third_party_reqs_email))
print('unique_third_party_reqs_email: ', len(unique_third_party_reqs_email))
# Out:
# third_party_reqs:  11950
# unique_third_party_reqs:  4327
# third_party_reqs_email:  11512
# unique_third_party_reqs_email:  4162

# %% [markdown]
# # Tracking Related Requests

# %%
tracker_related_reqs_df = df[~df.is_req_off_site_direction & (df.leak_type!='response_cookie_leaks') & (df.leak_type!='response_location_leaks') &(df.tracker_related) & ((df.final_url_domain == df.last_page_domain) | (df.initial_url == df.last_page_domain))]
unique_tracking_related_df = tracker_related_reqs_df.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'],keep='last')
email_leaks = tracker_related_reqs_df[tracker_related_reqs_df.search_type == 'email']
unique_email_leaks = email_leaks.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'])

# %%
print('tracker_related_reqs_df: ', len(tracker_related_reqs_df))
print('unique_tracking_related_df: ', len(unique_tracking_related_df))
print('email_leaks: ', len(email_leaks))
print('unique_email_leaks: ', len(unique_email_leaks))
# Out:
# tracker_related_reqs_df:  7509
# unique_tracking_related_df:  3180
# email_leaks:  7201
# unique_email_leaks:  3080

# %% [markdown]
# # High Level Statistics

# %%
print('Distinct websites where emails are leaked to both 1st, 3rd parties and tracker domains: ',len(all_reqs_email.drop_duplicates('initial_hostname')))
print('Distinct websites where emails are leaked to both 3rd parties and tracker domains: ',len(unique_third_party_reqs_email.drop_duplicates('initial_hostname')))
print('Distinct websites where emails are leaked to only tracker domains: ',len(unique_email_leaks.drop_duplicates('initial_hostname')))
# Out:
# Distinct websites where emails are leaked to both 1st, 3rd parties and tracker domains:  4049
# Distinct websites where emails are leaked to both 3rd parties and tracker domains:  2465
# Distinct websites where emails are leaked to only tracker domains:  1745

# %% [markdown]
# # Prominence

# %%
prominence_list = find_prominence(unique_tracking_related_df[unique_tracking_related_df.search_type=='email'])

# %%
prominence_df = pd.DataFrame(prominence_list, columns=['domain','prominence', 'number_of_sites'])

# %%
prominence_df.sort_values('prominence',ascending=False).head(20)
# Out:
#                 domain  prominence  number_of_sites
# 2          taboola.com    0.028498              304
# 14         bizible.com    0.013878              143
# 8        fullstory.com    0.006247              170
# 1           yandex.com    0.004896              103
# 3           zenaps.com    0.004797              109
# 4            awin1.com    0.004774              108
# 24          adroll.com    0.004160              120
# 20        zoominfo.com    0.003584               18
# 56  glassboxdigital.io    0.003502                6
# 0        listrakbi.com    0.002360               91
# 15        facebook.com    0.002306               38
# 40          bronto.com    0.002224               80
# 54           rlcdn.com    0.001865                7
# 10              okt.to    0.001779               30
# 27        lr-ingest.io    0.001624               20
# 36       salecycle.com    0.001574               30
# 41        gravatar.com    0.001551               37
# 23          pardot.com    0.001138               28
# 31  freshrelevance.com    0.000969               32
# 29        clearbit.com    0.000804               21

# %% [markdown]
# ## Leak types

# %%
unique_tracking_related_df.leak_type.value_counts()
# Out:
# url_leaks     2257
# post_leaks     923
# Name: leak_type, dtype: int64

# %% [markdown]
# ## Email leaks

# %%
unique_email_leaks[unique_email_leaks['rank_of_site']<2000].drop_duplicates('initial_url').sort_values('rank_of_site')[['initial_url', 'rank_of_site']].head(12)
# Out:
#              initial_url  rank_of_site
# 19326       usatoday.com           154
# 6385   independent.co.uk           243
# 3244         shopify.com           300
# 2687        marriott.com           328
# 6163      prnewswire.com           341
# 13170       newsweek.com           567
# 5790           prezi.com           705
# 16698          branch.io           754
# 8484          libsyn.com           887
# 9951     myanimelist.net          1089
# 7521      codecademy.com          1311
# 17136          cvent.com          1470

# %%
distinct_websites_email_leaks = unique_email_leaks.drop_duplicates('initial_hostname')

# %%
unique_email_leaks.encoding.value_counts()
# Out:
# unencoded                 616
# urlencode                 524
# sha256                    388
# urlencode-sha256          343
# urlencode-sha_salted_1    217
# sha_salted_1              217
# md5                       216
# urlencode-md5             159
# urlencode-urlencode       152
# base64                    102
# urlencode-base64           66
# sha1                       43
# urlencode-sha1             32
# urlencode-sha512            2
# sha512                      2
# base64-base64               1
# Name: encoding, dtype: int64

# %% [markdown]
# ## Tracked But NOT Sniffed

# %%
email_leaks[email_leaks.email_sniffed==False].drop_duplicates('initial_hostname')
# Out:
#                                         search search_type      encoding  \
# 3              cosiceve0+tirebuyer.com@gmail.c       email     urlencode
# 204            cosiceve0+academy.com@gmail.com       email     urlencode
# 570            cosiceve0+deliverr.com@gmail.co       email     unencoded
# 661              cosiceve0+omaze.com@gmail.com       email  sha_salted_1
# 839    cosiceve0+pro-essay-writer.com@gmail.co       email     unencoded
# ...                                        ...         ...           ...
# 20334        cosiceve0+megabonus.com@gmail.com       email     unencoded
# 20377             cosiceve0+bruna.nl@gmail.com       email     urlencode
# 20437       cosiceve0+protective.com@gmail.com       email     unencoded
# 20550              cosiceve0+ripl.com@gmail.co       email     urlencode
# 20685        cosiceve0+topodesigns.com@gmail.c       email     urlencode
#
#         leak_type                      final_url      final_url_domain  \
# 3       url_leaks     https://www.tirebuyer.com/         tirebuyer.com
# 204     url_leaks       https://www.academy.com/           academy.com
# 570    post_leaks          https://deliverr.com/          deliverr.com
# 661     url_leaks         https://www.omaze.com/             omaze.com
# 839    post_leaks  https://pro-essay-writer.com/  pro-essay-writer.com
# ...           ...                            ...                   ...
# 20334  post_leaks         https://megabonus.com/         megabonus.com
# 20377   url_leaks          https://www.bruna.nl/              bruna.nl
# 20437  post_leaks    https://www.protective.com/        protective.com
# 20550   url_leaks          https://www.ripl.com/              ripl.com
# 20685   url_leaks       https://topodesigns.com/       topodesigns.com
#
#                 initial_url      initial_hostname      last_page_domain  \
# 3             tirebuyer.com     www.tirebuyer.com         tirebuyer.com
# 204             academy.com       www.academy.com           academy.com
# 570            deliverr.com          deliverr.com          deliverr.com
# 661               omaze.com         www.omaze.com             omaze.com
# 839    pro-essay-writer.com  pro-essay-writer.com  pro-essay-writer.com
# ...                     ...                   ...                   ...
# 20334         megabonus.com         megabonus.com         megabonus.com
# 20377              bruna.nl          www.bruna.nl              bruna.nl
# 20437        protective.com    www.protective.com        protective.com
# 20550              ripl.com          www.ripl.com              ripl.com
# 20685       topodesigns.com       topodesigns.com       topodesigns.com
#
#                                              request_url  ... tracker_related  \
# 3      https://sca1.listrakbi.com/hWEdiEkwhcns/cart/f...  ...            True
# 204    https://sca1.listrakbi.com/c6dmlqeqKI30/cart/f...  ...            True
# 570    https://rs.fullstory.com/rec/bundle?OrgId=C8DB...  ...            True
# 661    https://www.zenaps.com/a/b.php?merchantId=1944...  ...            True
# 839    https://mc.yandex.ru/webvisor/25694771?wmode=0...  ...            True
# ...                                                  ...  ...             ...
# 20334  https://mc.yandex.ru/webvisor/37456880?wmode=0...  ...            True
# 20377  https://tr.datatrics.com/?action_name=Online%2...  ...            True
# 20437  https://rs.fullstory.com/rec/bundle?OrgId=TSE6...  ...            True
# 20550  https://www.upsellit.com/hound/saveData.jsp?si...  ...            True
# 20685  https://sca1.listrakbi.com/oJa2HYi6vkIz/cart/f...  ...            True
#
#                                             xpath                         id  \
# 3                 $x("//*[@id='ltkpopup-email']")             ltkpopup-email
# 204               $x("//*[@id='ltkpopup-email']")             ltkpopup-email
# 570           $x("//*[@id='login_email_header']")         login_email_header
# 661    $x("//*[@id='ozEmailOptinCustomerEmail']")  ozEmailOptinCustomerEmail
# 839                  $x("//*[@id='modal-email']")                modal-email
# ...                                           ...                        ...
# 20334         $x("//*[@id='auth-form-password']")         auth-form-password
# 20377                 $x("//*[@id='newsletter']")                 newsletter
# 20437                   $x("//*[@id='password']")                   password
# 20550        $x("//*[@id='input_comp-k9zv53du']")        input_comp-k9zv53du
# 20685             $x("//*[@id='ltkpopup-email']")             ltkpopup-email
#
#                                               latest_url  \
# 3                             https://www.tirebuyer.com/
# 204                             https://www.academy.com/
# 570                                https://deliverr.com/
# 661                               https://www.omaze.com/
# 839                        https://pro-essay-writer.com/
# ...                                                  ...
# 20334  https://auth.megabonus.com/?redirect_url=https...
# 20377                              https://www.bruna.nl/
# 20437             https://myaccount.protective.com/login
# 20550                              https://www.ripl.com/
# 20685                           https://topodesigns.com/
#
#        last_page_domain_iframe  is_req_off_site_direction  req_type  \
# 3                tirebuyer.com                      False     Image
# 204                academy.com                      False     Image
# 570               deliverr.com                      False       XHR
# 661                  omaze.com                      False     Image
# 839       pro-essay-writer.com                      False       XHR
# ...                        ...                        ...       ...
# 20334            megabonus.com                      False       XHR
# 20377                 bruna.nl                      False     Image
# 20437           protective.com                      False       XHR
# 20550                 ripl.com                      False    Script
# 20685          topodesigns.com                      False     Image
#
#       ublock_blocked  tds_blocked  \
# 3               True         True
# 204             True         True
# 570             True         True
# 661            False        False
# 839             True         True
# ...              ...          ...
# 20334           True         True
# 20377           True        False
# 20437           True         True
# 20550           True        False
# 20685           True         True
#
#                                      req_domain_category
# 3      ['Audience Measurement', 'Ad Motivated Trackin...
# 204    ['Audience Measurement', 'Ad Motivated Trackin...
# 570                      ['Analytics', 'Session Replay']
# 661                                                   []
# 839    ['Audience Measurement', 'Ad Motivated Trackin...
# ...                                                  ...
# 20334  ['Audience Measurement', 'Ad Motivated Trackin...
# 20377                                                 []
# 20437                    ['Analytics', 'Session Replay']
# 20550                                                 []
# 20685  ['Audience Measurement', 'Ad Motivated Trackin...
#
# [117 rows x 41 columns]

# %% [markdown]
# # Categories

# %%
categories_100K_final_dict = defaultdict(int)
for site_url, category in sites_categories.items():
    splitted_category = category.strip().split(', ')
    for each_category in splitted_category:
        categories_100K_final_dict[each_category] += 1

# %%
log_details['initial_hostname']
filled_sites = set(log_details['initial_hostname'])
log_details['initial_url'] = log_details.apply (lambda row: get_domain('http://' + row['initial_hostname']), axis=1)
categories_filled_final_dict = defaultdict(int)
filled_sites_domain_set = set(log_details.initial_url)
for site_url, category in sites_categories.items():
    if site_url in filled_sites_domain_set:
        splitted_category = category.strip().split(', ')
        for each_category in splitted_category:
            categories_filled_final_dict[each_category] += 1

# %%
unique_email_sites_df = unique_tracking_related_df[unique_tracking_related_df.search_type=='email'].drop_duplicates('initial_hostname')
leaky_categories_dict = defaultdict(int)
for index, row in unique_email_sites_df.iterrows():
    splitted_category = sites_categories[row['initial_url']].strip().split(', ')
#     print(row)
    for each_category in splitted_category:
        leaky_categories_dict[each_category] += 1

# %%
category_dict = dict()
tuples = []
for category, value in categories_100K_final_dict.items():
    filled_num = 0
    leaky_num = 0
    total_num = value
    if category in categories_filled_final_dict.keys():
        filled_num = categories_filled_final_dict[category]
    if category in leaky_categories_dict.keys():
        leaky_num = leaky_categories_dict[category]
    tuple_el = (category, total_num, filled_num, leaky_num)
    tuples.append(tuple_el)

# %%
categories_final = pd.DataFrame(tuples, columns=['category', 'total', 'filled', 'leaky']) 
categories_final['percentage'] = categories_final['leaky'] *100/ categories_final['filled']
categories_final['percentage'].astype(float).round(1)
categories_filtered = categories_final[categories_final.total>1000].sort_values(by='percentage', ascending=False)
categories_filtered['percentage'] = categories_filtered['percentage'].astype(float).round(1)
len(categories_filtered),categories_filtered
# Out:
# (23,
#                       category  total  filled  leaky  percentage
#  53             Fashion/Beauty   1669    1159    127        11.0
#  7             Online Shopping   5395    3656    333         9.1
#  18               General News   7390    3526    233         6.6
#  4                    Business  13462    8099    347         4.3
#  5           Software/Hardware   4933    2884    121         4.2
#  22    Marketing/Merchandising   4964    3143    111         3.5
#  39                     Travel   2519    1369     44         3.2
#  16          Internet Services   7974    4973    156         3.1
#  38                     Sports   1910    1070     26         2.4
#  26                     Health   2516    1491     35         2.3
#  23            Finance/Banking   3699    1978     44         2.2
#  64         Recreation/Hobbies   1098     740     14         1.9
#  12              Entertainment   5297    2587     45         1.7
#  8                Portal Sites   1544     749     13         1.7
#  17  Technical/Business Forums   1297     725     10         1.4
#  10        Education/Reference  10190    5798     79         1.4
#  6                  Blogs/Wiki   5415    3071     41         1.3
#  40         Public Information   2346    1079     12         1.1
#  33    Non-Profit/Advocacy/NGO   2713    1823     18         1.0
#  25                      Games   2173    1009      8         0.8
#  21        Government/Military   3754    1285      6         0.5
#  19              Uncategorized   1616     752      2         0.3
#  30                Pornography   1388     614      1         0.2)

# %% [markdown]
# ## Leaks on sites where CMP detected

# %%
len(tracker_related_reqs_df[tracker_related_reqs_df.was_cmp_detected].drop_duplicates('initial_hostname'))
# Out:
# 188

# %% [markdown]
# ## Leak types

# %%
unique_tracking_related_df.leak_type.value_counts()
# Out:
# url_leaks     2257
# post_leaks     923
# Name: leak_type, dtype: int64

# %% [markdown]
# # HTTP WEB SOCKET

# %%
unique_email_leaks['starts_with_wss'] = list(
    map(lambda x: x.startswith('wss'), unique_email_leaks['request_url']))
# Out:
# <ipython-input-81-afa97f9c504f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_email_leaks['starts_with_wss'] = list(

# %%
unique_email_leaks[unique_email_leaks.starts_with_wss].drop_duplicates('request_url_domain')
# Out:
#                                     search search_type   encoding   leak_type  \
# 753           cosiceve0+fastly.com@gmail.c       email  urlencode  post_leaks
# 913           cosiceve0+sunwing.ca@gmail.c       email  unencoded  post_leaks
# 10588  cosiceve0+cityfurniture.com@gmail.c       email  unencoded  post_leaks
#
#                             final_url   final_url_domain        initial_url  \
# 753           https://www.fastly.com/         fastly.com         fastly.com
# 913        https://www.sunwing.ca/en/         sunwing.ca         sunwing.ca
# 10588  https://www.cityfurniture.com/  cityfurniture.com  cityfurniture.com
#
#             initial_hostname   last_page_domain  \
# 753           www.fastly.com         fastly.com
# 913           www.sunwing.ca         sunwing.ca
# 10588  www.cityfurniture.com  cityfurniture.com
#
#                                  request_url  ...  \
# 753    wss://ws3.hotjar.com/api/v2/client/ws  ...
# 913             wss://am.freshrelevance.com/  ...
# 10588          wss://input.noibu.com/pv_part  ...
#
#                                                    xpath  \
# 753    $x("//*[@id='gatsby-focus-wrapper']/main/div/d...
# 913                $x("//*[@id='okta-signin-password']")
# 10588  $x("//*[@id='ds-wrap']/div[1]/div/div/div/div[...
#
#                          id                                    latest_url  \
# 753                     NaN                       https://www.fastly.com/
# 913    okta-signin-password  https://www.sunwing.ca/en/user-account/login
# 10588                   NaN                https://www.cityfurniture.com/
#
#        last_page_domain_iframe  is_req_off_site_direction   req_type  \
# 753                 fastly.com                      False  WebSocket
# 913                 sunwing.ca                      False  WebSocket
# 10588        cityfurniture.com                      False  WebSocket
#
#        ublock_blocked tds_blocked  \
# 753              True        True
# 913             False       False
# 10588            True       False
#
#                                      req_domain_category  starts_with_wss
# 753    ['Audience Measurement', 'Analytics', 'Session...             True
# 913                                                   []             True
# 10588                                                 []             True
#
# [3 rows x 42 columns]

# %%
unique_email_leaks['starts_with_http'] = list(
    map(lambda x: x.startswith('http:'), unique_email_leaks['request_url'])) 

unique_email_leaks[unique_email_leaks.starts_with_http].drop_duplicates('initial_hostname')
# Out:
# <ipython-input-83-03bdf40e02da>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_email_leaks['starts_with_http'] = list(
#                                              search search_type  \
# 639                 cosiceve0+ashland.com@gmail.com       email
# 2194                 cosiceve0+onfido.com@gmail.com       email
# 2660         cosiceve0+pressgazette.co.uk@gmail.com       email
# 3298          cosiceve0+rating-widget.com@gmail.com       email
# 6508   cosiceve0+advertisers.contobox.com@gmail.com       email
# 6608                  cosiceve0+ctbuh.org@gmail.com       email
# 8838                cosiceve0+vendini.com@gmail.com       email
# 12448       cosiceve0+affiliatesummit.com@gmail.com       email
# 12736                  cosiceve0+iiba.org@gmail.com       email
# 15088      cosiceve0+skyscrapercenter.com@gmail.com       email
# 15607                 cosiceve0+avoxi.com@gmail.com       email
# 16234               cosiceve0+resound.com@gmail.com       email
# 17333           cosiceve0+thebulletin.org@gmail.com       email
# 17378              cosiceve0+adcolony.com@gmail.com       email
# 18405       cosiceve0+complyadvantage.com@gmail.com       email
# 19051                   cosiceve0+hl7.org@gmail.com       email
# 19851  cosiceve0+actionforhealthykids.org@gmail.com       email
#
#                   encoding  leak_type                              final_url  \
# 639    urlencode-urlencode  url_leaks               https://www.ashland.com/
# 2194   urlencode-urlencode  url_leaks                    https://onfido.com/
# 2660   urlencode-urlencode  url_leaks            https://pressgazette.co.uk/
# 3298      urlencode-base64  url_leaks              http://rating-widget.com/
# 6508   urlencode-urlencode  url_leaks  https://www.advertisers.contobox.com/
# 6608   urlencode-urlencode  url_leaks                 https://www.ctbuh.org/
# 8838   urlencode-urlencode  url_leaks                   https://vendini.com/
# 12448  urlencode-urlencode  url_leaks       https://www.affiliatesummit.com/
# 12736  urlencode-urlencode  url_leaks                  https://www.iiba.org/
# 15088  urlencode-urlencode  url_leaks   https://www.ctbuh.org/?redirect=true
# 15607  urlencode-urlencode  url_leaks                 https://www.avoxi.com/
# 16234  urlencode-urlencode  url_leaks          https://www.resound.com/de-de
# 17333  urlencode-urlencode  url_leaks               https://thebulletin.org/
# 17378  urlencode-urlencode  url_leaks              https://www.adcolony.com/
# 18405  urlencode-urlencode  url_leaks           https://complyadvantage.com/
# 19051     urlencode-base64  url_leaks                    http://www.hl7.org/
# 19851  urlencode-urlencode  url_leaks  https://www.actionforhealthykids.org/
#
#                final_url_domain               initial_url  \
# 639                 ashland.com               ashland.com
# 2194                 onfido.com                onfido.com
# 2660         pressgazette.co.uk        pressgazette.co.uk
# 3298          rating-widget.com         rating-widget.com
# 6508               contobox.com              contobox.com
# 6608                  ctbuh.org                 ctbuh.org
# 8838                vendini.com               vendini.com
# 12448       affiliatesummit.com       affiliatesummit.com
# 12736                  iiba.org                  iiba.org
# 15088                 ctbuh.org      skyscrapercenter.com
# 15607                 avoxi.com                 avoxi.com
# 16234               resound.com               resound.com
# 17333           thebulletin.org           thebulletin.org
# 17378              adcolony.com              adcolony.com
# 18405       complyadvantage.com       complyadvantage.com
# 19051                   hl7.org                   hl7.org
# 19851  actionforhealthykids.org  actionforhealthykids.org
#
#                    initial_hostname          last_page_domain  \
# 639                 www.ashland.com               ashland.com
# 2194                     onfido.com                onfido.com
# 2660             pressgazette.co.uk        pressgazette.co.uk
# 3298              rating-widget.com         rating-widget.com
# 6508   www.advertisers.contobox.com              contobox.com
# 6608                  www.ctbuh.org                 ctbuh.org
# 8838                    vendini.com               vendini.com
# 12448       www.affiliatesummit.com       affiliatesummit.com
# 12736                  www.iiba.org                  iiba.org
# 15088      www.skyscrapercenter.com                 ctbuh.org
# 15607                 www.avoxi.com                 avoxi.com
# 16234               www.resound.com               resound.com
# 17333               thebulletin.org           thebulletin.org
# 17378              www.adcolony.com              adcolony.com
# 18405           complyadvantage.com       complyadvantage.com
# 19051                   www.hl7.org                   hl7.org
# 19851  www.actionforhealthykids.org  actionforhealthykids.org
#
#                                              request_url  ...  \
# 639    http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 2194   http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 2660   http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 3298   http://hn.inspectlet.com/pdata?d=cinmi,18273,3...  ...
# 6508   http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 6608   http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 8838   http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 12448  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 12736  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 15088  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 15607  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 16234  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 17333  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 17378  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 18405  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 19051  http://hn.inspectlet.com/pdata?d=cinmi,12369,1...  ...
# 19851  http://go.pardot.com/form/checkEmailAjax/accou...  ...
#
#                                   id  \
# 639    843993_107244pi_843993_107244
# 2194       885253_8614pi_885253_8614
# 2660   375012_527938pi_375012_527938
# 3298                             NaN
# 6508     764333_14369pi_764333_14369
# 6608       878592_4768pi_878592_4768
# 8838         814053_979pi_814053_979
# 12448  528152_120597pi_528152_120597
# 12736                  Emailpi_Email
# 15088      878592_4768pi_878592_4768
# 15607    673993_73068pi_673993_73068
# 16234  873281_207275pi_873281_207275
# 17333    878782_37527pi_878782_37527
# 17378  210152_121705pi_210152_121705
# 18405    352551_41923pi_352551_41923
# 19051                      mce-EMAIL
# 19851    21152_174465pi_21152_174465
#
#                                               latest_url  \
# 639    https://solving.ashland.com/l/843993/2020-08-2...
# 2194      https://go.onfido.com/l/885253/2020-09-16/29g1
# 2660   https://go.pressgazette.co.uk/l/375012/2021-01...
# 3298                           http://rating-widget.com/
# 6508   https://www2.contobox.com/l/764333/2019-10-03/...
# 6608   https://marketing.ctbuh.org/l/878592/2020-08-2...
# 8838   https://www2.vendini.com/l/814053/2019-11-01/2...
# 12448  https://info.affiliatesummit.com/l/528152/2020...
# 12736  https://go.iiba.org/email-signup?utm_source=We...
# 15088  https://marketing.ctbuh.org/l/878592/2020-08-2...
# 15607  https://marketing.avoxi.com/l/673993/2020-08-1...
# 16234       https://de.gn.com/l/873281/2020-06-29/glmj5n
# 17333   https://info.thebulletin.org/MediaAccountability
# 17378  https://go-pardot.adcolony.com/l/210152/2021-0...
# 18405  https://www2.complyadvantage.com/l/352551/2019...
# 19051                                http://www.hl7.org/
# 19851  https://www2.actionforhealthykids.org/l/21152/...
#
#         last_page_domain_iframe  is_req_off_site_direction  req_type  \
# 639                 ashland.com                      False       XHR
# 2194                 onfido.com                      False       XHR
# 2660         pressgazette.co.uk                      False       XHR
# 3298          rating-widget.com                      False     Image
# 6508               contobox.com                      False       XHR
# 6608                  ctbuh.org                      False       XHR
# 8838                vendini.com                      False       XHR
# 12448       affiliatesummit.com                      False       XHR
# 12736                  iiba.org                      False       XHR
# 15088                 ctbuh.org                      False       XHR
# 15607                 avoxi.com                      False       XHR
# 16234                    gn.com                      False       XHR
# 17333           thebulletin.org                      False       XHR
# 17378              adcolony.com                      False       XHR
# 18405       complyadvantage.com                      False       XHR
# 19051                   hl7.org                      False     Image
# 19851  actionforhealthykids.org                      False       XHR
#
#        ublock_blocked  tds_blocked  \
# 639              True         True
# 2194             True         True
# 2660             True         True
# 3298             True        False
# 6508             True         True
# 6608             True         True
# 8838             True         True
# 12448            True         True
# 12736            True         True
# 15088            True         True
# 15607            True         True
# 16234            True         True
# 17333            True         True
# 17378            True         True
# 18405            True         True
# 19051            True        False
# 19851            True         True
#
#                                      req_domain_category  starts_with_wss  \
# 639    ['Embedded Content', 'Ad Motivated Tracking', ...            False
# 2194   ['Embedded Content', 'Ad Motivated Tracking', ...            False
# 2660   ['Embedded Content', 'Ad Motivated Tracking', ...            False
# 3298   ['Analytics', 'Session Replay', 'Third-Party A...            False
# 6508   ['Embedded Content', 'Ad Motivated Tracking', ...            False
# 6608   ['Embedded Content', 'Ad Motivated Tracking', ...            False
# 8838   ['Embedded Content', 'Ad Motivated Tracking', ...            False
# 12448  ['Embedded Content', 'Ad Motivated Tracking', ...            False
# 12736  ['Embedded Content', 'Ad Motivated Tracking', ...            False
# 15088  ['Embedded Content', 'Ad Motivated Tracking', ...            False
# 15607  ['Embedded Content', 'Ad Motivated Tracking', ...            False
# 16234  ['Embedded Content', 'Ad Motivated Tracking', ...            False
# 17333  ['Embedded Content', 'Ad Motivated Tracking', ...            False
# 17378  ['Embedded Content', 'Ad Motivated Tracking', ...            False
# 18405  ['Embedded Content', 'Ad Motivated Tracking', ...            False
# 19051  ['Analytics', 'Session Replay', 'Third-Party A...            False
# 19851  ['Embedded Content', 'Ad Motivated Tracking', ...            False
#
#        starts_with_http
# 639                True
# 2194               True
# 2660               True
# 3298               True
# 6508               True
# 6608               True
# 8838               True
# 12448              True
# 12736              True
# 15088              True
# 15607              True
# 16234              True
# 17333              True
# 17378              True
# 18405              True
# 19051              True
# 19851              True
#
# [17 rows x 43 columns]
