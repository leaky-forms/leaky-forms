# %%
import pandas as pd
import pickle
from collections import defaultdict
from leak_common import get_domain, find_prominence
import matplotlib.pyplot as plt

# %%
with open('../pkls_csvs/extra_tracker_domains.pkl', 'rb') as handle:
    extra_tracker_domains = pickle.load(handle)

# %% [markdown]
# # Read from pickles

# %%
log_details = pd.read_pickle("../pkls_csvs/fra_log_details.pkl")
df = pd.read_csv("../pkls_csvs/desktop_no_action_fra_crawl.csv", sep='\t', encoding='utf-8')
## Due to copyright restrictions, we can't share categories info
# with open('../pkls_csvs/categories.pkl', 'rb') as handle:
#     sites_categories = pickle.load(handle)

# %% [markdown]
# # Additional Columns

# %%
df['is_blocked'] = df.easy_list_blocked | df.easy_privacy_blocked | df.disconnect_blocked | df.whotracksme_blocked | (df.tds_blocked) | (df.ublock_blocked) | (df.request_url_domain.isin(extra_tracker_domains))

# %%
df['tracker_related'] = df.third_party_req & df.is_blocked

# %% [markdown]
# # All Requests

# %%
all_reqs = df
unique_all_reqs = all_reqs.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'])
all_reqs_email = all_reqs[all_reqs.search_type == 'email']
unique_all_reqs_email = all_reqs_email.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'])

# %%
print('all_reqs: ', len(all_reqs))
print('unique_all_reqs: ', len(unique_all_reqs))
print('all_reqs_email: ', len(all_reqs_email))
print('unique_all_reqs_email: ', len(unique_all_reqs_email))
# Out:
# all_reqs:  22340
# unique_all_reqs:  7887
# all_reqs_email:  19379
# unique_all_reqs_email:  6551

# %% [markdown]
# # Third Party Requests

# %%
third_party_reqs = df[df.third_party_req & ~df.is_req_off_site_direction]
unique_third_party_reqs = third_party_reqs.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'])
third_party_reqs_email = third_party_reqs[third_party_reqs.search_type == 'email']
unique_third_party_reqs_email = third_party_reqs_email.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'])

# %%
print('third_party_reqs: ', len(third_party_reqs))
print('unique_third_party_reqs: ', len(unique_third_party_reqs))
print('third_party_reqs_email: ', len(third_party_reqs_email))
print('unique_third_party_reqs_email: ', len(unique_third_party_reqs_email))
# Out:
# third_party_reqs:  12967
# unique_third_party_reqs:  4647
# third_party_reqs_email:  12415
# unique_third_party_reqs_email:  4442

# %% [markdown]
# # Tracking Related Requests

# %%
tracker_related_reqs_df = df[~df.is_req_off_site_direction & (df.leak_type!='response_cookie_leaks') & (df.leak_type!='response_location_leaks') &(df.tracker_related) & ((df.final_url_domain == df.last_page_domain) | (df.initial_url == df.last_page_domain))]
#tracker_related_reqs_df = df[(df.leak_type!='response_cookie_leaks') & (df.leak_type!='response_location_leaks') &(df.tracker_related) & ((df.final_url_domain == df.last_page_domain) | (df.initial_url == df.last_page_domain))]
unique_tracking_related_df = tracker_related_reqs_df.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'],keep='last')
email_leaks = tracker_related_reqs_df[tracker_related_reqs_df.search_type == 'email']
unique_email_leaks = email_leaks.drop_duplicates(['initial_hostname', 'search_type', 'request_url_domain', 'encoding', 'leak_type'])

# %%
print('tracker_related_reqs_df: ', len(tracker_related_reqs_df))
print('unique_tracking_related_df: ', len(unique_tracking_related_df))
print('email_leaks: ', len(email_leaks))
print('unique_email_leaks: ', len(unique_email_leaks))
# Out:
# tracker_related_reqs_df:  8088
# unique_tracking_related_df:  3366
# email_leaks:  7713
# unique_email_leaks:  3242

# %% [markdown]
# # High Level Statistics

# %%
print('Distinct websites where emails are leaked to both 1st, 3rd parties and tracker domains: ',len(all_reqs_email.drop_duplicates('initial_hostname')))
print('Distinct websites where emails are leaked to both 3rd parties and tracker domains: ',len(unique_third_party_reqs_email.drop_duplicates('initial_hostname')))
print('Distinct websites where emails are leaked to only tracker domains: ',len(unique_email_leaks.drop_duplicates('initial_hostname')))
# Out:
# Distinct websites where emails are leaked to both 1st, 3rd parties and tracker domains:  4395
# Distinct websites where emails are leaked to both 3rd parties and tracker domains:  2633
# Distinct websites where emails are leaked to only tracker domains:  1844

# %% [markdown]
# # Prominence

# %%
prominence_list = find_prominence(unique_tracking_related_df[unique_tracking_related_df.search_type=='email'])

# %%
prominence_df = pd.DataFrame(prominence_list, columns=['domain','prominence', 'number_of_sites'])

# %%
prominence_df.sort_values('prominence',ascending=False).head(20)
# Out:
#                 domain  prominence  number_of_sites
# 17         taboola.com    0.030292              327
# 22         bizible.com    0.017296              160
# 11       fullstory.com    0.007558              182
# 3           zenaps.com    0.004873              113
# 4            awin1.com    0.004850              112
# 5           yandex.com    0.004194              121
# 20          adroll.com    0.003962              117
# 62  glassboxdigital.io    0.003188                6
# 1        listrakbi.com    0.002485               91
# 0           bronto.com    0.002458               90
# 29           rlcdn.com    0.001994               11
# 39       salecycle.com    0.001751               35
# 37        gravatar.com    0.001666               38
# 19        facebook.com    0.001481               21
# 30          pardot.com    0.001265               36
# 13              okt.to    0.001135               31
# 6   freshrelevance.com    0.001022               34
# 26     gaconnector.com    0.000964               17
# 63        zoominfo.com    0.000919               18
# 15        smarterhq.io    0.000835                6

# %% [markdown]
# ## Leak types

# %%
unique_tracking_related_df.leak_type.value_counts()
# Out:
# url_leaks     2362
# post_leaks    1004
# Name: leak_type, dtype: int64

# %% [markdown]
# ## Email leaks

# %%
unique_email_leaks[unique_email_leaks['rank_of_site']<2000].drop_duplicates('initial_url').sort_values('rank_of_site')[['initial_url', 'rank_of_site']].head(12)
# Out:
#              initial_url  rank_of_site
# 20907       usatoday.com           154
# 12723         trello.com           242
# 6835   independent.co.uk           243
# 3357         shopify.com           300
# 2780        marriott.com           328
# 13998       newsweek.com           567
# 6211           prezi.com           705
# 18033          branch.io           754
# 15334     prothomalo.com          1153
# 8002      codecademy.com          1311
# 14511      azcentral.com          1543
# 17336     cloudflare.net          1571

# %%
distinct_websites_email_leaks = unique_email_leaks.drop_duplicates('initial_hostname')

# %%
unique_email_leaks.encoding.value_counts()
# Out:
# unencoded                 673
# urlencode                 562
# sha256                    390
# urlencode-sha256          360
# urlencode-sha_salted_1    225
# sha_salted_1              225
# md5                       210
# urlencode-urlencode       170
# urlencode-md5             149
# base64                    112
# urlencode-base64           70
# sha1                       52
# urlencode-sha1             38
# base64-urlencode            2
# base64-md5                  1
# base64-base64               1
# urlencode-sha512            1
# sha512                      1
# Name: encoding, dtype: int64

# %% [markdown]
# ## Tracked But NOT Sniffed

# %%
email_leaks[email_leaks.email_sniffed==False].drop_duplicates('initial_hostname')
# Out:
#                                            search search_type   encoding  \
# 13             cosicadam0+tirebuyer.com@gmail.com       email  urlencode
# 79                   cosicadam0+ru-mi.com@gmail.c       email  urlencode
# 203               cosicadam0+academy.com@gmail.co       email  urlencode
# 257        cosicadam0+rincondelvago.com@gmail.com       email     sha256
# 322            cosicadam0+caratlane.com@gmail.com       email     sha256
# ...                                           ...         ...        ...
# 21933           cosicadam0+megabonus.com@gmail.co       email  unencoded
# 21985               cosicadam0+bruna.nl@gmail.com       email  urlencode
# 22038           cosicadam0+protective.com@gmail.c       email  unencoded
# 22293  cosicadam0+courierpostonline.com@gmail.com       email     sha256
# 22321        cosicadam0+topodesigns.com@gmail.com       email  urlencode
#
#         leak_type                           final_url       final_url_domain  \
# 13      url_leaks          https://www.tirebuyer.com/          tirebuyer.com
# 79      url_leaks                  https://ru-mi.com/              ru-mi.com
# 203     url_leaks            https://www.academy.com/            academy.com
# 257     url_leaks      https://www.rincondelvago.com/      rincondelvago.com
# 322    post_leaks          https://www.caratlane.com/          caratlane.com
# ...           ...                                 ...                    ...
# 21933  post_leaks              https://megabonus.com/          megabonus.com
# 21985   url_leaks               https://www.bruna.nl/               bruna.nl
# 22038  post_leaks         https://www.protective.com/         protective.com
# 22293   url_leaks  https://www.courierpostonline.com/  courierpostonline.com
# 22321   url_leaks            https://topodesigns.com/        topodesigns.com
#
#                  initial_url           initial_hostname  \
# 13             tirebuyer.com          www.tirebuyer.com
# 79                 ru-mi.com                  ru-mi.com
# 203              academy.com            www.academy.com
# 257        rincondelvago.com      www.rincondelvago.com
# 322            caratlane.com          www.caratlane.com
# ...                      ...                        ...
# 21933          megabonus.com              megabonus.com
# 21985               bruna.nl               www.bruna.nl
# 22038         protective.com         www.protective.com
# 22293  courierpostonline.com  www.courierpostonline.com
# 22321        topodesigns.com            topodesigns.com
#
#             last_page_domain  \
# 13             tirebuyer.com
# 79                 ru-mi.com
# 203              academy.com
# 257        rincondelvago.com
# 322            caratlane.com
# ...                      ...
# 21933          megabonus.com
# 21985               bruna.nl
# 22038         protective.com
# 22293  courierpostonline.com
# 22321        topodesigns.com
#
#                                              request_url  ...  \
# 13     https://sca1.listrakbi.com/hWEdiEkwhcns/cart/f...  ...
# 79     https://cdn.caltat.com/RegisterEvent.ashx?code...  ...
# 203    https://sca1.listrakbi.com/c6dmlqeqKI30/cart/f...  ...
# 257    https://trc.taboola.com/sg/tfa-eid/1/um/?uils=...  ...
# 322                         https://www.facebook.com/tr/  ...
# ...                                                  ...  ...
# 21933  https://mc.yandex.ru/webvisor/37456880?wmode=0...  ...
# 21985  https://tr.datatrics.com/?action_name=Online%2...  ...
# 22038  https://rs.fullstory.com/rec/bundle?OrgId=TSE6...  ...
# 22293  https://trc.taboola.com/sg/tfa-eid/1/um/?uils=...  ...
# 22321  https://sca1.listrakbi.com/oJa2HYi6vkIz/cart/f...  ...
#
#       is_req_off_site_direction  req_domain_entity  sniff_initiators  \
# 13                        False            Listrak             set()
# 79                        False                NaN             set()
# 203                       False            Listrak             set()
# 257                       False      Taboola, Inc.             set()
# 322                       False     Facebook, Inc.             set()
# ...                         ...                ...               ...
# 21933                     False         Yandex LLC             set()
# 21985                     False                NaN             set()
# 22038                     False          FullStory             set()
# 22293                     False      Taboola, Inc.             set()
# 22321                     False            Listrak             set()
#
#        is_req_domain_among_sniff_initiators  req_type  ublock_blocked  \
# 13                                    False     Image            True
# 79                                    False    Script            True
# 203                                   False     Image            True
# 257                                   False     Image            True
# 322                                   False     Other            True
# ...                                     ...       ...             ...
# 21933                                 False       XHR            True
# 21985                                 False     Image            True
# 22038                                 False       XHR            True
# 22293                                 False     Image            True
# 22321                                 False     Image            True
#
#        tds_blocked                       req_domain_category  ends_with_c  \
# 13            True        Ad Motivated Tracking, Advertising        False
# 79           False  Analytics and Tracking, Cart Abandonment         True
# 203           True        Ad Motivated Tracking, Advertising        False
# 257           True        Ad Motivated Tracking, Advertising        False
# 322           True        Ad Motivated Tracking, Advertising        False
# ...            ...                                       ...          ...
# 21933         True        Ad Motivated Tracking, Advertising        False
# 21985        False   Analytics and Tracking, Personalization        False
# 22038         True                 Session Replay, Analytics         True
# 22293         True        Ad Motivated Tracking, Advertising        False
# 22321         True        Ad Motivated Tracking, Advertising        False
#
#        ends_with_co
# 13            False
# 79            False
# 203            True
# 257           False
# 322           False
# ...             ...
# 21933          True
# 21985         False
# 22038         False
# 22293         False
# 22321         False
#
# [170 rows x 47 columns]

# %% [markdown]
# # Categories

# %%
categories_100K_final_dict = defaultdict(int)
for site_url, category in sites_categories.items():
    splitted_category = category.strip().split(', ')
    for each_category in splitted_category:
        categories_100K_final_dict[each_category] += 1

# %%
log_details['initial_hostname']
filled_sites = set(log_details['initial_hostname'])
log_details['initial_url'] = log_details.apply (lambda row: get_domain('http://' + row['initial_hostname']), axis=1)
categories_filled_final_dict = defaultdict(int)
filled_sites_domain_set = set(log_details.initial_url)
for site_url, category in sites_categories.items():
    if site_url in filled_sites_domain_set:
        splitted_category = category.strip().split(', ')
        for each_category in splitted_category:
            categories_filled_final_dict[each_category] += 1

# %%
unique_email_sites_df = unique_tracking_related_df[unique_tracking_related_df.search_type=='email'].drop_duplicates('initial_hostname')
leaky_categories_dict = defaultdict(int)
for index, row in unique_email_sites_df.iterrows():
    splitted_category = row['category'].strip().split(', ')
#     print(row)
    for each_category in splitted_category:
        leaky_categories_dict[each_category] += 1

# %%
category_dict = dict()
tuples = []
for category, value in categories_100K_final_dict.items():
    filled_num = 0
    leaky_num = 0
    total_num = value
    if category in categories_filled_final_dict.keys():
        filled_num = categories_filled_final_dict[category]
    if category in leaky_categories_dict.keys():
        leaky_num = leaky_categories_dict[category]
    tuple_el = (category, total_num, filled_num, leaky_num)
    tuples.append(tuple_el)

# %%
categories_final = pd.DataFrame(tuples, columns=['category', 'total', 'filled', 'leaky']) 
categories_final['percentage'] = categories_final['leaky'] *100/ categories_final['filled']
categories_final['percentage'].astype(float).round(1)
categories_filtered = categories_final[categories_final.total>1000].sort_values(by='percentage', ascending=False)
categories_filtered['percentage'] = categories_filtered['percentage'].astype(float).round(1)
len(categories_filtered),categories_filtered
# Out:
# (23,
#                       category  total  filled  leaky  percentage
#  53             Fashion/Beauty   1669    1176    131        11.1
#  7             Online Shopping   5395    3658    345         9.4
#  18               General News   7390    3579    235         6.6
#  5           Software/Hardware   4933    2834    138         4.9
#  4                    Business  13462    7805    377         4.8
#  22    Marketing/Merchandising   4964    3167    119         3.8
#  16          Internet Services   7974    4627    171         3.7
#  39                     Travel   2519    1355     46         3.4
#  26                     Health   2516    1389     44         3.2
#  23            Finance/Banking   3699    1505     41         2.7
#  38                     Sports   1910    1044     28         2.7
#  8                Portal Sites   1544     682     17         2.5
#  10        Education/Reference  10190    4185     87         2.1
#  12              Entertainment   5297    2610     47         1.8
#  64         Recreation/Hobbies   1098     754     13         1.7
#  6                  Blogs/Wiki   5415    3095     42         1.4
#  17  Technical/Business Forums   1297     717      9         1.3
#  33    Non-Profit/Advocacy/NGO   2713    1842     21         1.1
#  25                      Games   2173     925      9         1.0
#  40         Public Information   2346    1049      8         0.8
#  21        Government/Military   3754     939      5         0.5
#  19              Uncategorized   1616     636      3         0.5
#  30                Pornography   1388     528      0         0.0)

# %% [markdown]
# ## Leaks on sites where CMP detected

# %%
len(tracker_related_reqs_df[tracker_related_reqs_df.was_cmp_detected].drop_duplicates('initial_hostname'))
# Out:
# 202

# %% [markdown]
# ## Is req domain among the sniff initiators?

# %%
not_in_sniff_inits = set(unique_email_leaks[~unique_email_leaks.is_req_domain_among_sniff_initiators].drop_duplicates('initial_hostname').initial_hostname)
in_sniff_inits = set(unique_email_leaks[unique_email_leaks.is_req_domain_among_sniff_initiators].drop_duplicates('initial_hostname').initial_hostname)
len(not_in_sniff_inits.difference(in_sniff_inits)), len(not_in_sniff_inits), len(in_sniff_inits), len(unique_email_leaks.drop_duplicates('initial_hostname'))
# Out:
# (565, 635, 1279, 1844)

# %%
unique_tracking_related_df.leak_type.value_counts()
# Out:
# url_leaks     2362
# post_leaks    1004
# Name: leak_type, dtype: int64

# %% [markdown]
# # HTTP WEB SOCKET

# %%
unique_email_leaks['starts_with_wss'] = list(
    map(lambda x: x.startswith('wss'), unique_email_leaks['request_url']))

# %%
unique_email_leaks[unique_email_leaks.starts_with_wss].drop_duplicates('request_url_domain')
# Out:
#                                       search search_type   encoding  \
# 67           cosicadam0+chopard.com@gmail.co       email  unencoded
# 379       cosicadam0+bettercloud.com@gmail.c       email  urlencode
# 11162  cosicadam0+cityfurniture.com@gmail.co       email  unencoded
#
#         leak_type                       final_url   final_url_domain  \
# 67     post_leaks   https://www.chopard.com/intl/        chopard.com
# 379    post_leaks    https://www.bettercloud.com/    bettercloud.com
# 11162  post_leaks  https://www.cityfurniture.com/  cityfurniture.com
#
#              initial_url       initial_hostname   last_page_domain  \
# 67           chopard.com        www.chopard.com        chopard.com
# 379      bettercloud.com    www.bettercloud.com    bettercloud.com
# 11162  cityfurniture.com  www.cityfurniture.com  cityfurniture.com
#
#                                   request_url  ... req_domain_entity  \
# 67               wss://am.freshrelevance.com/  ...               NaN
# 379    wss://ws11.hotjar.com/api/v2/client/ws  ...               NaN
# 11162           wss://input.noibu.com/pv_part  ...               NaN
#
#                                       sniff_initiators  \
# 67     {'chopard.com', 'dkpklk99llpj0.cloudfront.net'}
# 379       {'bizible.com', 'marketo.com', 'hotjar.com'}
# 11162                                            set()
#
#        is_req_domain_among_sniff_initiators   req_type  ublock_blocked  \
# 67                                    False  WebSocket           False
# 379                                   False  WebSocket            True
# 11162                                 False  WebSocket            True
#
#        tds_blocked                              req_domain_category  \
# 67           False  Analytics and Tracking, Conversion Optimization
# 379           True                        Session Replay, Analytics
# 11162        False                          Widgets, Error Tracking
#
#       ends_with_c  ends_with_co  starts_with_wss
# 67          False          True             True
# 379          True         False             True
# 11162       False          True             True
#
# [3 rows x 48 columns]

# %%
unique_email_leaks['starts_with_http'] = list(
    map(lambda x: x.startswith('http:'), unique_email_leaks['request_url'])) 

unique_email_leaks[unique_email_leaks.starts_with_http].drop_duplicates('initial_hostname')
# Out:
#                                               search search_type  \
# 697                 cosicadam0+ashland.com@gmail.com       email
# 2260                 cosicadam0+onfido.com@gmail.com       email
# 2739         cosicadam0+pressgazette.co.uk@gmail.com       email
# 4138            cosicadam0+ntrepidcorp.com@gmail.com       email
# 6948   cosicadam0+advertisers.contobox.com@gmail.com       email
# 7040                  cosicadam0+ctbuh.org@gmail.com       email
# 11555               cosicadam0+eastern.edu@gmail.com       email
# 13186       cosicadam0+affiliatesummit.com@gmail.com       email
# 13503                  cosicadam0+iiba.org@gmail.com       email
# 16225      cosicadam0+skyscrapercenter.com@gmail.com       email
# 16804                 cosicadam0+avoxi.com@gmail.com       email
# 17501               cosicadam0+resound.com@gmail.com       email
# 18856              cosicadam0+adcolony.com@gmail.com       email
# 19901       cosicadam0+complyadvantage.com@gmail.com       email
# 21440  cosicadam0+actionforhealthykids.org@gmail.com       email
#
#                   encoding  leak_type                              final_url  \
# 697    urlencode-urlencode  url_leaks               https://www.ashland.com/
# 2260   urlencode-urlencode  url_leaks                    https://onfido.com/
# 2739   urlencode-urlencode  url_leaks            https://pressgazette.co.uk/
# 4138   urlencode-urlencode  url_leaks               https://ntrepidcorp.com/
# 6948   urlencode-urlencode  url_leaks  https://www.advertisers.contobox.com/
# 7040   urlencode-urlencode  url_leaks                 https://www.ctbuh.org/
# 11555  urlencode-urlencode  url_leaks               https://www.eastern.edu/
# 13186  urlencode-urlencode  url_leaks       https://www.affiliatesummit.com/
# 13503  urlencode-urlencode  url_leaks                  https://www.iiba.org/
# 16225  urlencode-urlencode  url_leaks   https://www.ctbuh.org/?redirect=true
# 16804  urlencode-urlencode  url_leaks                 https://www.avoxi.com/
# 17501  urlencode-urlencode  url_leaks          https://www.resound.com/de-de
# 18856  urlencode-urlencode  url_leaks              https://www.adcolony.com/
# 19901  urlencode-urlencode  url_leaks           https://complyadvantage.com/
# 21440  urlencode-urlencode  url_leaks  https://www.actionforhealthykids.org/
#
#                final_url_domain               initial_url  \
# 697                 ashland.com               ashland.com
# 2260                 onfido.com                onfido.com
# 2739         pressgazette.co.uk        pressgazette.co.uk
# 4138            ntrepidcorp.com           ntrepidcorp.com
# 6948               contobox.com              contobox.com
# 7040                  ctbuh.org                 ctbuh.org
# 11555               eastern.edu               eastern.edu
# 13186       affiliatesummit.com       affiliatesummit.com
# 13503                  iiba.org                  iiba.org
# 16225                 ctbuh.org      skyscrapercenter.com
# 16804                 avoxi.com                 avoxi.com
# 17501               resound.com               resound.com
# 18856              adcolony.com              adcolony.com
# 19901       complyadvantage.com       complyadvantage.com
# 21440  actionforhealthykids.org  actionforhealthykids.org
#
#                    initial_hostname          last_page_domain  \
# 697                 www.ashland.com               ashland.com
# 2260                     onfido.com                onfido.com
# 2739             pressgazette.co.uk        pressgazette.co.uk
# 4138                ntrepidcorp.com           ntrepidcorp.com
# 6948   www.advertisers.contobox.com              contobox.com
# 7040                  www.ctbuh.org                 ctbuh.org
# 11555               www.eastern.edu               eastern.edu
# 13186       www.affiliatesummit.com       affiliatesummit.com
# 13503                  www.iiba.org                  iiba.org
# 16225      www.skyscrapercenter.com                 ctbuh.org
# 16804                 www.avoxi.com                 avoxi.com
# 17501               www.resound.com               resound.com
# 18856              www.adcolony.com              adcolony.com
# 19901           complyadvantage.com       complyadvantage.com
# 21440  www.actionforhealthykids.org  actionforhealthykids.org
#
#                                              request_url  ...  \
# 697    http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 2260   http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 2739   http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 4138   http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 6948   http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 7040   http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 11555  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 13186  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 13503  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 16225  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 16804  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 17501  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 18856  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 19901  http://go.pardot.com/form/checkEmailAjax/accou...  ...
# 21440  http://go.pardot.com/form/checkEmailAjax/accou...  ...
#
#                      sniff_initiators  is_req_domain_among_sniff_initiators  \
# 697    {'ashland.com', 'gstatic.com'}                                 False
# 2260                   {'onfido.com'}                                 False
# 2739           {'pressgazette.co.uk'}                                 False
# 4138              {'ntrepidcorp.com'}                                 False
# 6948                 {'contobox.com'}                                 False
# 7040                    {'ctbuh.org'}                                 False
# 11555                 {'eastern.edu'}                                 False
# 13186         {'affiliatesummit.com'}                                 False
# 13503                           set()                                 False
# 16225                   {'ctbuh.org'}                                 False
# 16804    {'bizible.com', 'avoxi.com'}                                 False
# 17501                      {'gn.com'}                                 False
# 18856                {'adcolony.com'}                                 False
# 19901         {'complyadvantage.com'}                                 False
# 21440    {'actionforhealthykids.org'}                                 False
#
#        req_type  ublock_blocked  tds_blocked  \
# 697         XHR            True         True
# 2260        XHR            True         True
# 2739        XHR            True         True
# 4138        XHR            True         True
# 6948        XHR            True         True
# 7040        XHR            True         True
# 11555       XHR            True         True
# 13186       XHR            True         True
# 13503       XHR            True         True
# 16225       XHR            True         True
# 16804       XHR            True         True
# 17501       XHR            True         True
# 18856       XHR            True         True
# 19901       XHR            True         True
# 21440       XHR            True         True
#
#                       req_domain_category  ends_with_c ends_with_co  \
# 697    Ad Motivated Tracking, Advertising        False        False
# 2260   Ad Motivated Tracking, Advertising        False        False
# 2739   Ad Motivated Tracking, Advertising        False        False
# 4138   Ad Motivated Tracking, Advertising        False        False
# 6948   Ad Motivated Tracking, Advertising        False        False
# 7040   Ad Motivated Tracking, Advertising        False        False
# 11555  Ad Motivated Tracking, Advertising        False        False
# 13186  Ad Motivated Tracking, Advertising        False        False
# 13503  Ad Motivated Tracking, Advertising        False        False
# 16225  Ad Motivated Tracking, Advertising        False        False
# 16804  Ad Motivated Tracking, Advertising        False        False
# 17501  Ad Motivated Tracking, Advertising        False        False
# 18856  Ad Motivated Tracking, Advertising        False        False
# 19901  Ad Motivated Tracking, Advertising        False        False
# 21440  Ad Motivated Tracking, Advertising        False        False
#
#        starts_with_wss  starts_with_http
# 697              False              True
# 2260             False              True
# 2739             False              True
# 4138             False              True
# 6948             False              True
# 7040             False              True
# 11555            False              True
# 13186            False              True
# 13503            False              True
# 16225            False              True
# 16804            False              True
# 17501            False              True
# 18856            False              True
# 19901            False              True
# 21440            False              True
#
# [15 rows x 49 columns]
